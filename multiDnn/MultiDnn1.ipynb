# %%
import pandas as pd
import os
#import matplotlib.pyplot as plt
import tensorflow as tf
from datetime import datetime
from tensorflow.contrib.layers import fully_connected, batch_norm
import math
import numpy as np
import random

# %%
df = pd.read_csv('./DL_final_project/DL_Taiwan_data/sinica/201701_Taiwan.csv',
                 usecols=['Date','Time','PM2.5','PM10','PM1','Temperature','Humidity','lon','lat'])
#把201701_Taiwan.csv的header的' lat',' lon'改成'lat','lon' (多了空格)
#len(df)

# %%
def getAreaSeriesFromIdx(s):
    #f = s.mask(s['in_area'], s['lon_g']*3+s['lat_g']+1, axis=0)['lat']
    f = s.mask(s['in_area'], s['lat_g']+1, axis=0)['lat']
    f = f.where(s['in_area'], 0)
    return f

# %%
#if train_for_taiwan:
#    df = df[(df['lat']>= 21 )& (df['lat'] <= 27)&(df['lon']>=118)&(df['lon']<=122)]

# %%
df
# Out:
#                Date      Time  PM2.5  PM10   PM1  Temperature  Humidity  \
# 0        2017-01-01  08:00:00   31.0  33.0  22.0        22.75      78.0
# 1        2017-01-01  08:00:00   59.0  76.0  40.0        21.25      92.0
# 2        2017-01-01  08:00:00   31.0  33.0  22.0        22.75      78.0
# 3        2017-01-01  08:00:00   59.0  76.0  40.0        21.25      92.0
# 4        2017-01-01  08:00:00   31.0  33.0  22.0        22.75      78.0
# 5        2017-01-01  08:00:00   59.0  76.0  40.0        21.25      92.0
# 6        2017-01-01  08:00:01   39.0  46.0  28.0        23.62      77.0
# 7        2017-01-01  08:00:01   39.0  46.0  28.0        23.62      77.0
# 8        2017-01-01  08:00:01   39.0  46.0  28.0        23.62      77.0
# 9        2017-01-01  08:00:01   70.0  87.0  52.0        23.50      85.0
# 10       2017-01-01  08:00:01   70.0  87.0  52.0        23.50      85.0
# 11       2017-01-01  08:00:01   70.0  87.0  52.0        23.50      85.0
# 12       2017-01-01  08:00:02   16.0   0.0   0.0        23.50      92.0
# 13       2017-01-01  08:00:02   21.0   0.0   0.0        20.75     100.0
# 14       2017-01-01  08:00:02   16.0   0.0   0.0        23.50      92.0
# 15       2017-01-01  08:00:02   21.0   0.0   0.0        20.75     100.0
# 16       2017-01-01  08:00:02   16.0   0.0   0.0        23.50      92.0
# 17       2017-01-01  08:00:02   21.0   0.0   0.0        20.75     100.0
# 18       2017-01-01  08:00:03   22.0   0.0   0.0        20.87     100.0
# 19       2017-01-01  08:00:03   22.0   0.0   0.0        20.87     100.0
# 20       2017-01-01  08:00:03   22.0   0.0   0.0        20.87     100.0
# 21       2017-01-01  08:00:04   78.0  95.0  57.0        22.25      82.0
# 22       2017-01-01  08:00:04   78.0  95.0  57.0        22.25      82.0
# 23       2017-01-01  08:00:04   78.0  95.0  57.0        22.25      82.0
# 24       2017-01-01  08:00:05   57.0  74.0  39.0        21.25      89.0
# 25       2017-01-01  08:00:05   57.0  74.0  39.0        21.25      89.0
# 26       2017-01-01  08:00:05   57.0  74.0  39.0        21.25      89.0
# 27       2017-01-01  08:00:05   12.0   0.0   0.0        23.37     100.0
# 28       2017-01-01  08:00:05   15.0   0.0   0.0        22.75     100.0
# 29       2017-01-01  08:00:05   12.0   0.0   0.0        23.37     100.0
# ...             ...       ...    ...   ...   ...          ...       ...
# 4930337  2017-01-31  23:59:35   22.0  25.0  18.0        11.87      29.0
# 4930338  2017-01-31  23:59:35   45.0  54.0  31.0        22.62      85.0
# 4930339  2017-01-31  23:59:36    9.0  11.0   6.0        22.50      68.0
# 4930340  2017-01-31  23:59:37   19.0   0.0   0.0        18.00      99.0
# 4930341  2017-01-31  23:59:38   13.0  14.0   9.0        21.50      83.0
# 4930342  2017-01-31  23:59:38    8.0   9.0   5.0        24.62      62.0
# 4930343  2017-01-31  23:59:39   10.0   0.0   0.0        22.37      75.0
# 4930344  2017-01-31  23:59:40   35.0  42.0  24.0        26.87      61.0
# 4930345  2017-01-31  23:59:41   13.0  14.0  12.0        31.87      58.0
# 4930346  2017-01-31  23:59:42   18.0  21.0  13.0        24.62      73.0
# 4930347  2017-01-31  23:59:43   12.0   0.0   0.0        20.50      72.0
# 4930348  2017-01-31  23:59:43   25.0  32.0  17.0        21.75      81.0
# 4930349  2017-01-31  23:59:43   11.0   0.0   0.0        20.12      81.0
# 4930350  2017-01-31  23:59:45   18.0  20.0  13.0        10.50      41.0
# 4930351  2017-01-31  23:59:45   20.0  23.0  14.0        23.25      70.0
# 4930352  2017-01-31  23:59:46   34.0  44.0  23.0        24.25      71.0
# 4930353  2017-01-31  23:59:47   36.0  41.0  26.0        22.62      83.0
# 4930354  2017-01-31  23:59:48   39.0  51.0  27.0        24.62      76.0
# 4930355  2017-01-31  23:59:49   36.0  40.0  27.0        12.00      34.0
# 4930356  2017-01-31  23:59:49   40.0  48.0  29.0        24.25      76.0
2017-01-31 23:59:50    23     True    1.0    1.0
# 4930361  25.016  121.405 2017-01-31 23:59:50    23     True    1.0    2.0
# 4930362  25.086  121.518 2017-01-31 23:59:53    23     True    1.0    2.0
# 4930363  34.891  128.690 2017-01-31 23:59:56    23    False    5.0    6.0
# 4930364  24.085  120.558 2017-01-31 23:59:57    23     True    1.0    1.0
# 4930365  35.169  128.057 2017-01-31 23:59:58    23    False    5.0    7.0
# 4930366  24.112  120.667 2017-01-31 23:59:59    23     True    1.0    1.0
#
#          area
# 0         3.0
# 1         1.0
# 2         3.0
# 3         1.0
# 4         3.0
# 5         1.0
# 6         2.0
# 7         2.0
# 8         2.0
# 9         1.0
# 10        1.0
# 11        1.0
# 12        3.0
# 13        3.0
# 14        3.0
# 15        3.0
# 16        3.0
# 17        3.0
# 18        3.0
# 19        3.0
# 20        3.0
# 21        2.0
# 22        2.0
# 23        2.0
# 24        2.0
# 25        2.0
# 26        2.0
# 27        3.0
# 28        3.0
# 29        3.0
# ...       ...
# 4930337   0.0
# 4930338   1.0
# 4930339   2.0
# 4930340   3.0
# 4930341   2.0
# 4930342   2.0
# 4930343   3.0
# 4930344   1.0
# 4930345   0.0
# 4930346   2.0
# 4930347   3.0
# 4930348   1.0
# 4930349   3.0
# 4930350   0.0
# 4930351   2.0
# 4930352   3.0
# 4930353   1.0
# 4930354   3.0
# 4930355   0.0
# 4930356   1.0
# 4930357   1.0
# 4930358   2.0
# 4930359   2.0
# 4930360   2.0
# 4930361   3.0
# 4930362   3.0
# 4930363   0.0
# 4930364   2.0
# 4930365   0.0
# 4930366   2.0
#
# [4930367 rows x 15 columns]

# %%
root_logdir = "tf_logs"
batch_log_step = 50
early_stopping_epochs = 10

# %%
def dnn(area_num, export_dir, X_1, y_1, X_2, y_2):
    tf.reset_default_graph()
    
    print("model will be exported in",export_dir)
    
    # logs
    start_time = datetime.now()
    now = start_time.strftime("%Y%m%d_%H%M%S")
    logdir = "./{}/run-{}".format(root_logdir, now)
    print("now=",now)
    
    # dnn graph defs
    n_input = 7
    n_epochs = 100
    n_hidden = [100,100,10]
    act_fn = tf.nn.sigmoid
    learning_rate = 0.001
    batch_normalization = False
    batch_size = 10000
    #batch_size = 1000 #小範圍測試用
    mult_bias = 1000

    # I/O
    with tf.name_scope("Input"):
        X = tf.placeholder(tf.float32, [None, n_input], name="X")
        is_training = tf.placeholder(tf.bool, shape=(), name="is_training")
    with tf.name_scope("Output"):
        y = tf.placeholder(tf.float32, [None, 1], name="y")
        y_biased = y/mult_bias
    
    # batch norm 
    he_init = tf.contrib.layers.variance_scaling_initializer()
    with tf.name_scope("BatchNormArgs"):
        bn_params = {
            'is_training': is_training,
            'decay': 0.99,
            'updates_collections': None,
            'scale': True
        }
    
    # DNN
    with tf.name_scope("DNN"):
        with tf.contrib.framework.arg_scope(
                [fully_connected],
                weights_initializer = he_init,
                normalizer_fn = batch_norm if batch_normalization else None,
                normalizer_params = bn_params if batch_normalization else None
                ):
            h1=fully_connected(X ,n_hidden[0],activation_fn=act_fn,scope="h1")
            h2=fully_connected(h1,n_hidden[1],activation_fn=act_fn,scope="h2")
            h3=fully_connected(h2,n_hidden[2],activation_fn=act_fn,scope="h3")
        logits=fully_connected(h3, 1, weights_initializer=he_init, activation_fn=act_fn,scope="out")
    
    with tf.name_scope("Cost"):
        #cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y), name="cost")
        cost = tf.losses.mean_squared_error(logits, y_biased)
    with tf.name_scope("AdamOptimizer"):
        optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate)
        minimizer = optimizer.minimize(cost)
    
    init = tf.global_variables_initializer()
    with tf.name_scope("ModelSaver"):
        saver = tf.train.Saver()
    
    with tf.name_scope("Predict"):
        predict = tf.multiply(logits, mult_bias, name="predict")
        
    with tf.name_scope("Error"):
        ave_of_batch_y = tf.reduce_mean(y_biased)
        error = tf.abs(logits - y_biased)/ave_of_batch_y
        relative_err = tf.reduce_mean(error)
    
    with tf.name_scope("Summaries-Train"):
        cost_summary = tf.summary.scalar('cost_function',cost)
        error_summary = tf.summary.scalar('relative_err',relative_err)
    with tf.name_scope("Summaries-Validation"):
        v_cost_summary = tf.summary.scalar('v_cost_function',cost)
        v_error_summary = tf.summary.scalar('v_relative_err',relative_err)
    file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())
    
    with tf.Session() as sess:
        sess.run(init)
        
        total_batch = len(X_1)//batch_size
        #total_batch = validation_idx_start//batch_size
        print("Total batch:",total_batch)
        #X_va, y_va = dfa_X[validation_idx_start:test_idx_start], dfa_Y[validation_idx_start:test_idx_start]
        X_va = X_2
        y_va = y_2
        #X_test = X_3
        #y_test = y_3
        
        best_va_err_triggered = False
        best_va_err = 0
        early_stopping_triggered = False
        stopping_epoch = 0
        step = 0
        save_path = ""
        best_save_path = ""
        
        perm = np.arange(len(X_1))
        np.random.shuffle(perm)
        X_t = X_1[perm]
        y_t = y_1[perm]
        
        for epoch in range(n_epochs):
            for batch in range(total_batch):
                X_ba = X_t[batch*batch_size: (batch+1)*batch_size]
                y_ba = y_t[batch*batch_size: (batch+1)*batch_size]
                _, c = sess.run([minimizer, cost], feed_dict = {is_training: True, X:X_ba, y:y_ba})
                
                if batch % batch_log_step == 0:
                    print("Epoch %4d batch %5d"%(epoch,batch))
                    cost_summary_str = cost_summary.eval(feed_dict={is_training:False, X:X_ba, y:y_ba})
                    step = epoch * total_batch + batch
                    file_writer.add_summary(cost_summary_str, step)
                    error_summary_str = error_summary.eval(feed_dict={is_training:False, X:X_ba, y:y_ba})
                    file_writer.add_summary(error_summary_str, step)
            
            save_path = saver.save(sess, "./checkpoint/model_"+now+".ckpt")
            va_err, va_cost = sess.run([relative_err, cost], feed_dict={is_training:False, X:X_va, y:y_va})
            va_l = sess.run(predict, feed_dict={is_training:False, X:X_va, y:y_va})
            rnd_result_idx = random.randint(0, len(X_va)-1)
            
            print(va_l[rnd_result_idx], y_va[rnd_result_idx]) # print 1st prediction result
            v_error_summary_str = v_error_summary.eval(feed_dict={is_training:False, X:X_va, y:y_va})
            file_writer.add_summary(v_error_summary_str, step)
            v_cost_summary_str = v_cost_summary.eval(feed_dict={is_training:False, X:X_va, y:y_va})
            file_writer.add_summary(v_cost_summary_str, step)
            print("Epoch %4d val.cost %3.6f val.err %3.2f%%"%(epoch,va_cost,va_err*100),end=" ")
            
            if best_va_err_triggered:
                if va_err < best_va_err:
                    print("best")
                    stopping_epoch = 0
                    best_va_err = va_err
                    
                    best_save_path = saver.save(sess, "./best_model/model_"+now)
                else:
                    stopping_epoch += 1
                    print("stopping %3d"%stopping_epoch)
                if stopping_epoch >= early_stopping_epochs:
                    early_stopping_triggered = True
                    print("Early stopping triggered: Step: %10d, val.err %3.2f%%"%(step, va_err*100))
            else:
                best_va_err = va_err
                best_va_err_triggered = True
                print("best")
                best_save_path = saver.save(sess, "./best_model/model_"+now)
            
            if early_stopping_triggered:
                break
        
        finish_time = datetime.now()
        print("best model saved to:", best_save_path)
        file_writer.close()
        elapse_time = finish_time - start_time
        total_seconds = elapse_time.total_seconds()
        print("Total time:", total_seconds)
        
        #X_test = dfa_X[test_idx_start:idx_end]
        #y_test = dfa_Y[test_idx_start:idx_end]
        #saver.restore(sess, "./best_model/model_"+now)
        #best_err = relative_err.eval({is_training: False, X: X_test, y: y_test})
        #print("Test Err: %3.2f%%"%(best_err*100))
        
        builder = tf.saved_model.builder.SavedModelBuilder(export_dir)
        builder.add_meta_graph_and_variables(sess, ["tag"], signature_def_map= {
            "model": tf.saved_model.signature_def_utils.predict_signature_def(
                inputs= {"X": X, "is_training": is_training},
                outputs= {"predict": predict})
        })
        builder.save()
        
        """
        print("Predicting...")
        predict_values = sess.run(predict, feed_dict={is_training: False, X: X_w})
        print("Predict End")
        return predict_values
        """

# %%
# df2: validation
# df3: test
df_v = pd.read_csv('./DL_final_project/DL_Taiwan_data/sinica/201702_Taiwan.csv',
                 usecols=['Date','Time','PM2.5','PM10','PM1','Temperature','Humidity','lon','lat'])
test_idx_start = math.floor(len(df_v)*0.5)
df2 = df_v[:test_idx_start]
df3 = df_v[test_idx_start:]

# %%
df = df.assign(Timestamp = pd.to_datetime(df['Date']+' '+df['Time']))
df = df.assign(Hour = lambda x: x['Timestamp'].dt.hour)
df = df.assign(in_area = lambda x:(x['lat']>= 21 )& (x['lat'] <= 27)&(x['lon']>=118)&(x['lon']<=122))
df = df.assign(lon_g = lambda x:(x.lon-118)//2)
df = df.assign(lat_g = lambda x:(x.lat-21)//2)
df = df.assign(area = getAreaSeriesFromIdx)

df2 = df2.assign(Timestamp = pd.to_datetime(df2['Date']+' '+df2['Time']))
df2 = df2.assign(Hour = lambda x: x['Timestamp'].dt.hour)
df2 = df2.assign(in_area = lambda x:(x['lat']>= 21 )& (x['lat'] <= 27)&(x['lon']>=118)&(x['lon']<=122))
df2 = df2.assign(lon_g = lambda x:(x.lon-118)//2)
df2 = df2.assign(lat_g = lambda x:(x.lat-21)//2)
df2 = df2.assign(area = getAreaSeriesFromIdx)

# %%
df
# Out:
#                Date      Time  PM2.5  PM10   PM1  Temperature  Humidity  \
# 0        2017-01-01  08:00:00   31.0  33.0  22.0        22.75      78.0
# 1        2017-01-01  08:00:00   59.0  76.0  40.0        21.25      92.0
# 2        2017-01-01  08:00:00   31.0  33.0  22.0        22.75      78.0
# 3        2017-01-01  08:00:00   59.0  76.0  40.0        21.25      92.0
#
2017-01-31 23:59:50    23     True    1.0    1.0
# 4930359  24.949  121.383 2017-01-31 23:59:50    23     True    1.0    1.0
# 4930360  24.083  120.752 2017-01-31 23:59:50    23     True    1.0    1.0
# 4930361  25.016  121.405 2017-01-31 23:59:50    23     True    1.0    2.0
# 4930362  25.086  121.518 2017-01-31 23:59:53    23     True    1.0    2.0
# 4930363  34.891  128.690 2017-01-31 23:59:56    23    False    5.0    6.0
# 4930364  24.085  120.558 2017-01-31 23:59:57    23     True    1.0    1.0
# 4930365  35.169  128.057 2017-01-31 23:59:58    23    False    5.0    7.0
# 4930366  24.112  120.667 2017-01-31 23:59:59    23     True    1.0    1.0
#
#          area
# 0         3.0
# 1         1.0
# 2         3.0
# 3         1.0
# 4         3.0
# 5         1.0
# 6         2.0
# 7         2.0
# 8         2.0
# 9         1.0
# 10        1.0
# 11        1.0
# 12        3.0
# 13        3.0
# 14        3.0
# 15        3.0
# 16        3.0
# 17        3.0
# 18        3.0
# 19        3.0
# 20        3.0
# 21        2.0
# 22        2.0
# 23        2.0
# 24        2.0
# 25        2.0
# 26        2.0
# 27        3.0
# 28        3.0
# 29        3.0
# ...       ...
# 4930337   0.0
# 4930338   1.0
# 4930339   2.0
# 4930340   3.0
# 4930341   2.0
# 4930342   2.0
# 4930343   3.0
# 4930344   1.0
# 4930345   0.0
# 4930346   2.0
# 4930347   3.0
# 4930348   1.0
# 4930349   3.0
# 4930350   0.0
# 4930351   2.0
# 4930352   3.0
# 4930353   1.0
# 4930354   3.0
# 4930355   0.0
# 4930356   1.0
# 4930357   1.0
# 4930358   2.0
# 4930359   2.0
# 4930360   2.0
# 4930361   3.0
# 4930362   3.0
# 4930363   0.0
# 4930364   2.0
# 4930365   0.0
# 4930366   2.0
#
# [4930367 rows x 15 columns]

# %%
area_num = 4
# check folder
export_check_num = 1
export_dir = './final_model/'
while os.path.exists(export_dir):
    export_check_num += 1
    export_dir = './final_model_'+str(export_check_num)+'/'
for a in range(area_num):
    print('area', a)
    
    dfa = df[df['area'] == a]
    df_X = dfa[['Hour','PM10','PM1','Temperature','Humidity','lon','lat']]
    df_X = df_X.values
    df_Y = dfa[['PM2.5']]
    df_Y = df_Y.values
    print('train len =', len(df_X))
    
    df2a = df2[df2['area']==a]
    df2_X = df2a[['Hour','PM10','PM1','Temperature','Humidity','lon','lat']]
    df2_X = df2_X.values
    df2_Y = df2a[['PM2.5']]
    df2_Y = df2_Y.values
    print('test len =',len(df2_X))
    
    
    export_dir_area = export_dir + 'area_'+str(a)+"/"
    dfa.describe(include="all")
    dnn(a, export_dir_area, df_X, df_Y, df2_X, df2_Y)
# Out:
# area 0
# train len = 339197
# test len = 97343
# model will be exported in ./final_model_5/area_0/
# now= 20180616_193134
# Total batch: 33
# Epoch    0 batch     0
# [ 322.6812439] [54]
# Epoch    0 val.cost 0.088151 val.err 1185.65% best
# Epoch    1 batch     0
# [ 259.47064209] [53]
# Epoch    1 val.cost 0.056192 val.err 945.87% best
# Epoch    2 batch     0
# [ 241.28405762] [12]
# Epoch    2 val.cost 0.047278 val.err 867.24% best
# Epoch    3 batch     0
# [ 227.36203003] [8]
# Epoch    3 val.cost 0.041273 val.err 809.98% best
# Epoch    4 batch     0
# [ 215.6085968] [20]
# Epoch    4 val.cost 0.036508 val.err 761.48% best
# Epoch    5 batch     0
# [ 205.01446533] [71]
# Epoch    5 val.cost 0.032544 val.err 718.65% best
# Epoch    6 batch     0
# [ 195.1645813] [17]
# Epoch    6 val.cost 0.029170 val.err 680.09% best
# Epoch    7 batch     0
# [ 186.31031799] [15]
# Epoch    7 val.cost 0.026260 val.err 644.98% best
# Epoch    8 batch     0
# [ 178.29949951] [19]
# Epoch    8 val.cost 0.023719 val.err 612.67% best
# Epoch    9 batch     0
# [ 170.80305481] [10]
# Epoch    9 val.cost 0.021499 val.err 582.98% best
# Epoch   10 batch     0
# [ 163.81414795] [37]
# Epoch   10 val.cost 0.019541 val.err 555.47% best
# Epoch   11 batch     0
# [ 157.48072815] [19]
# Epoch   11 val.cost 0.017798 val.err 529.80% best
# Epoch   12 batch     0
# [ 151.29475403] [59]
# Epoch   12 val.cost 0.016222 val.err 505.46% best
# Epoch   13 batch     0
# [ 145.12355042] [18]
# Epoch   13 val.cost 0.014692 val.err 480.65% best
# Epoch   14 batch     0
# [ 137.30986023] [4]
# Epoch   14 val.cost 0.012885 val.err 449.61% best
# Epoch   15 batch     0
# [ 129.36186218] [8]
# Epoch   15 val.cost 0.011131 val.err 417.29% best
# Epoch   16 batch     0
# [ 122.23735809] [41]
# Epoch   16 val.cost 0.009724 val.err 389.40% best
# Epoch   17 batch     0
# [ 116.28071594] [43]
# Epoch   17 val.cost 0.008577 val.err 365.13% best
# Epoch   18 batch     0
# [ 110.81463623] [43]
# Epoch   18 val.cost 0.007628 val.err 343.74% best
# Epoch   19 batch     0
# [ 106.09749603] [11]
# Epoch   19 val.cost 0.006831 val.err 324.69% best
# Epoch   20 batch     0
# [ 101.75766754] [29]
# Epoch   20 val.cost 0.006154 val.err 307.60% best
# Epoch   21 batch     0
# [ 97.938797] [21]
# Epoch   21 val.cost 0.005574 val.err 292.16% best
# Epoch   22 batch     0
# [ 94.44637299] [16]
# Epoch   22 val.cost 0.005072 val.err 278.12% best
# Epoch   23 batch     0
# [ 91.14398193] [25]
# Epoch   23 val.cost 0.004635 val.err 265.28% best
# Epoch   24 batch     0
# [ 88.23603058] [4]
# Epoch   24 val.cost 0.004252 val.err 253.49% best
# Epoch   25 batch     0
# [ 85.51892853] [7]
# Epoch   25 val.cost 0.003914 val.err 242.61% best
# Epoch   26 batch     0
# [ 82.9479599] [52]
# Epoch   26 val.cost 0.003614 val.err 232.55% best
# Epoch   27 batch     0
# [ 80.61193848] [21]
# Epoch   27 val.cost 0.003347 val.err 223.21% best
# Epoch   28 batch     0
# [ 78.43930817] [33]
# Epoch   28 val.cost 0.003108 val.err 214.52% best
# Epoch   29 batch     0
# [ 76.39598846] [27]
# Epoch   29 val.cost 0.002893 val.err 206.40% best
# Epoch   30 batch     0
# [ 74.46867371] [31]
# Epoch   30 val.cost 0.002700 val.err 198.81% best
# Epoch   31 batch     0
# [ 72.63954926] [26]
# Epoch   31 val.cost 0.002525 val.err 191.70% best
# Epoch   32 batch     0
# [ 70.97042847] [17]
# Epoch   32 val.cost 0.002366 val.err 185.02% best
# Epoch   33 batch     0
# [ 69.36750031] [23]
# Epoch   33 val.cost 0.002221 val.err 178.74% best
# Epoch   34 batch     0
# [ 67.81954193] [27]
# Epoch   34 val.cost 0.002089 val.err 172.83% best
# Epoch   35 batch     0
# [ 66.39411163] [10]
# Epoch   35 val.cost 0.001968 val.err 167.25% best
# Epoch   36 batch     0
# [ 65.03470612] [27]
# Epoch   36 val.cost 0.001857 val.err 161.99% best
# Epoch   37 batch     0
# [ 63.73614883] [16]
# Epoch   37 val.cost 0.001756 val.err 157.01% best
# Epoch   38 batch     0
# [ 62.50849533] [53]
# Epoch   38 val.cost 0.001662 val.err 152.30% best
# Epoch   39 batch     0
# [ 61.33325958] [60]
# Epoch   39 val.cost 0.001576 val.err 147.83% best
# Epoch   40 batch     0
# [ 60.23361206] [66]
# Epoch   40 val.cost 0.001496 val.err 143.60% best
# Epoch   41 batch     0
# [ 59.16981125] [16]
# Epoch   41 val.cost 0.001422 val.err 139.57% best
# Epoch   42 batch     0
# [ 58.13737869] [25]
# Epoch   42 val.cost 0.001353 val.err 135.75% best
# Epoch   43 batch     0
# [ 57.14673233] [45]
# Epoch   43 val.cost 0.001290 val.err 132.11% best
# Epoch   44 batch     0
# [ 56.23953247] [11]
# Epoch   44 val.cost 0.001231 val.err 128.65% best
# Epoch   45 batch     0
# [ 55.35578156] [16]
# Epoch   45 val.cost 0.001176 val.err 125.36% best
# Epoch   46 batch     0
# [ 54.47711182] [42]
# Epoch   46 val.cost 0.001124 val.err 122.23% best
# Epoch   47 batch     0
# [ 53.66106415] [21]
# Epoch   47 val.cost 0.001076 val.err 119.25% best
# Epoch   48 batch     0
# [ 52.86946106] [27]
# Epoch   48 val.cost 0.001031 val.err 116.41% best
# Epoch   49 batch     0
# [ 52.09924316] [16]
# Epoch   49 val.cost 0.000990 val.err 113.71% best
# Epoch   50 batch     0
# [ 51.37531662] [49]
# Epoch   50 val.cost 0.000950 val.err 111.13% best
# Epoch   51 batch     0
# [ 50.66594696] [16]
# Epoch   51 val.cost 0.000914 val.err 108.68% best
# Epoch   52 batch     0
# [ 50.00052643] [10]
# Epoch   52 val.cost 0.000879 val.err 106.33% best
# Epoch   53 batch     0
# [ 49.32653046] [73]
# Epoch   53 val.cost 0.000847 val.err 104.10% best
# Epoch   54 batch     0
# [ 48.68407822] [33]
# Epoch   54 val.cost 0.000816 val.err 101.97% best
# Epoch   55 batch     0
# [ 48.09075928] [14]
# Epoch   55 val.cost 0.000788 val.err 99.93% best
# Epoch   56 batch     0
# [ 47.50046539] [10]
# Epoch   56 val.cost 0.000761 val.err 98.00% best
# Epoch   57 batch     0
# [ 46.9177742] [23]
# Epoch   57 val.cost 0.000735 val.err 96.14% best
# Epoch   58 batch     0
# [ 46.36802292] [24]
# Epoch   58 val.cost 0.000711 val.err 94.38% best
# Epoch   59 batch     0
# [ 45.83037567] [36]
# Epoch   59 val.cost 0.000689 val.err 92.69% best
# Epoch   60 batch     0
# [ 45.31596375] [7]
# Epoch   60 val.cost 0.000667 val.err 91.08% best
# Epoch   61 batch     0
# [ 44.80386353] [39]
# Epoch   61 val.cost 0.000647 val.err 89.54% best
# Epoch   62 batch     0
# [ 44.32538986] [15]
# Epoch   62 val.cost 0.000628 val.err 88.07% best
# Epoch   63 batch     0
# [ 43.84181213] [89]
# Epoch   63 val.cost 0.000610 val.err 86.65% best
# Epoch   64 batch     0
# [ 43.39463043] [26]
# Epoch   64 val.cost 0.000593 val.err 85.31% best
# Epoch   65 batch     0
# [ 42.9386673] [36]
# Epoch   65 val.cost 0.000577 val.err 84.01% best
# Epoch   66 batch     0
# [ 42.52080536] [16]
# Epoch   66 val.cost 0.000562 val.err 82.79% best
# Epoch   67 batch     0
# [ 42.10699463] [5]
# Epoch   67 val.cost 0.000547 val.err 81.60% best
# Epoch   68 batch     0
# [ 41.69118881] [18]
# Epoch   68 val.cost 0.000534 val.err 80.47% best
# Epoch   69 batch     0
# [ 41.29863358] [31]
# Epoch   69 val.cost 0.000521 val.err 79.39% best
# Epoch   70 batch     0
# [ 40.92034531] [39]
# Epoch   70 val.cost 0.000508 val.err 78.34% best
# Epoch   71 batch     0
# [ 40.54227829] [30]
# Epoch   71 val.cost 0.000496 val.err 77.36% best
# Epoch   72 batch     0
# [ 40.17401886] [55]
# Epoch   72 val.cost 0.000485 val.err 76.40% best
# Epoch   73 batch     0
# [ 39.82939148] [25]
# Epoch   73 val.cost 0.000475 val.err 75.49% best
# Epoch   74 batch     0
# [ 39.47628021] [26]
# Epoch   74 val.cost 0.000465 val.err 74.61% best
# Epoch   75 batch     0
# [ 39.15724182] [17]
# Epoch   75 val.cost 0.000455 val.err 73.76% best
# Epoch   76 batch     0
# [ 38.83577347] [14]
# Epoch   76 val.cost 0.000446 val.err 72.96% best
# Epoch   77 batch     0
# [ 38.50654602] [49]
# Epoch   77 val.cost 0.000437 val.err 72.18% best
# Epoch   78 batch     0
# [ 38.20969772] [29]
# Epoch   78 val.cost 0.000429 val.err 71.43% best
# Epoch   79 batch     0
# [ 37.91111755] [15]
# Epoch   79 val.cost 0.000421 val.err 70.71% best
# Epoch   80 batch     0
# [ 37.6169548] [11]
# Epoch   80 val.cost 0.000414 val.err 70.04% best
# Epoch   81 batch     0
# [ 37.33042526] [26]
# Epoch   81 val.cost 0.000407 val.err 69.38% best
# Epoch   82 batch     0
# [ 37.06020737] [27]
# Epoch   82 val.cost 0.000400 val.err 68.74% best
# Epoch   83 batch     0
# [ 36.78897858] [32]
# Epoch   83 val.cost 0.000394 val.err 68.14% best
# Epoch   84 batch     0
# [ 36.52669144] [11]
# Epoch   84 val.cost 0.000388 val.err 67.56% best
# Epoch   85 batch     0
# [ 36.26582336] [23]
# Epoch   85 val.cost 0.000382 val.err 67.00% best
# Epoch   86 batch     0
# [ 36.01421356] [39]
# Epoch   86 val.cost 0.000376 val.err 66.45% best
# Epoch   87 batch     0
# [ 35.78756332] [24]
# Epoch   87 val.cost 0.000371 val.err 65.94% best
# Epoch   88 batch     0
# [ 35.53812027] [40]
# Epoch   88 val.cost 0.000366 val.err 65.44% best
# Epoch   89 batch     0
# [ 35.31232452] [28]
# Epoch   89 val.cost 0.000361 val.err 64.96% best
# Epoch   90 batch     0
# [ 35.07781219] [50]
# Epoch   90 val.cost 0.000357 val.err 64.49% best
# Epoch   91 batch     0
# [ 34.86828232] [35]
# Epoch   91 val.cost 0.000352 val.err 64.05% best
# Epoch   92 batch     0
# [ 34.65815353] [10]
# Epoch   92 val.cost 0.000348 val.err 63.63% best
# Epoch   93 batch     0
# [ 34.43742752] [33]
# Epoch   93 val.cost 0.000344 val.err 63.22% best
# Epoch   94 batch     0
# [ 34.24600601] [32]
# Epoch   94 val.cost 0.000340 val.err 62.82% best
# Epoch   95 batch     0
# [ 34.04659653] [20]
# Epoch   95 val.cost 0.000337 val.err 62.43% best
# Epoch   96 batch     0
# [ 33.85186005] [15]
# Epoch   96 val.cost 0.000333 val.err 62.07% best
# Epoch   97 batch     0
# [ 33.66374207] [14]
# Epoch   97 val.cost 0.000330 val.err 61.72% best
# Epoch   98 batch     0
# [ 33.47076797] [50]
# Epoch   98 val.cost 0.000327 val.err 61.38% best
# Epoch   99 batch     0
# [ 33.29100037] [19]
# Epoch   99 val.cost 0.000324 val.err 61.05% best
# best model saved to: ./best_model/model_20180616_193134
# Total time: 397.961975
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b'./final_model_5/area_0/saved_model.pb'
# area 1
# train len = 997856
# test len = 276990
# model will be exported in ./final_model_5/area_1/
# now= 20180616_193816
# Total batch: 99
# Epoch    0 batch     0
# Epoch    0 batch    50
# [ 111.37592316] [58]
# Epoch    0 val.cost 0.003805 val.err 111.29% best
# Epoch    1 batch     0
# Epoch    1 batch    50
# [ 90.93844604] [65]
# Epoch    1 val.cost 0.001829 val.err 73.90% best
# Epoch    2 batch     0
# Epoch    2 batch    50
# [ 80.14319611] [73]
# Epoch    2 val.cost 0.001108 val.err 55.42% best
# Epoch    3 batch     0
# Epoch    3 batch    50
# [ 72.84725952] [48]
# Epoch    3 val.cost 0.000754 val.err 44.22% best
# Epoch    4 batch     0
# Epoch    4 batch    50
# [ 67.81957245] [35]
# Epoch    4 val.cost 0.000556 val.err 36.66% best
# Epoch    5 batch     0
# Epoch    5 batch    50
# [ 63.23006821] [54]
# Epoch    5 val.cost 0.000383 val.err 28.15% best
# Epoch    6 batch     0
# Epoch    6 batch    50
# [ 59.42308807] [30]
# Epoch    6 val.cost 0.000286 val.err 23.04% best
# Epoch    7 batch     0
# Epoch    7 batch    50
# [ 55.87008667] [43]
# Epoch    7 val.cost 0.000215 val.err 18.88% best
# Epoch    8 batch     0
# Epoch    8 batch    50
# [ 81.59621429] [83]
# Epoch    8 val.cost 0.000163 val.err 15.62% best
# Epoch    9 batch     0
# Epoch    9 batch    50
# [ 61.43148804] [61]
# Epoch    9 val.cost 0.000130 val.err 13.36% best
# Epoch   10 batch     0
# Epoch   10 batch    50
# [ 51.04297256] [52]
# Epoch   10 val.cost 0.000107 val.err 11.71% best
# Epoch   11 batch     0
# Epoch   11 batch    50
# [ 46.44184113] [26]
# Epoch   11 val.cost 0.000091 val.err 10.45% best
# Epoch   12 batch     0
# Epoch   12 batch    50
# [ 44.90470886] [30]
# Epoch   12 val.cost 0.000079 val.err 9.47% best
# Epoch   13 batch     0
# Epoch   13 batch    50
# [ 86.82209778] [84]
# Epoch   13 val.cost 0.000070 val.err 8.69% best
# Epoch   14 batch     0
# Epoch   14 batch    50
# [ 54.5316658] [55]
# Epoch   14 val.cost 0.000063 val.err 8.07% best
# Epoch   15 batch     0
# Epoch   15 batch    50
# [ 41.15584564] [28]
# Epoch   15 val.cost 0.000057 val.err 7.57% best
# Epoch   16 batch     0
# Epoch   16 batch    50
# [ 40.40116882] [40]
# Epoch   16 val.cost 0.000053 val.err 7.12% best
# Epoch   17 batch     0
# Epoch   17 batch    50
# [ 55.88275146] [56]
# Epoch   17 val.cost 0.000049 val.err 6.76% best
# Epoch   18 batch     0
# Epoch   18 batch    50
# [ 38.75809479] [36]
# Epoch   18 val.cost 0.000046 val.err 6.45% best
# Epoch   19 batch     0
# Epoch   19 batch    50
# [ 75.82215118] [76]
# Epoch   19 val.cost 0.000043 val.err 6.19% best
# Epoch   20 batch     0
# Epoch   20 batch    50
# [ 42.05331039] [42]
# Epoch   20 val.cost 0.000041 val.err 5.97% best
# Epoch   21 batch     0
# Epoch   21 batch    50
# [ 36.21715927] [35]
# Epoch   21 val.cost 0.000039 val.err 5.74% best
# Epoch   22 batch     0
# Epoch   22 batch    50
# [ 63.39286423] [64]
# Epoch   22 val.cost 0.000037 val.err 5.57% best
# Epoch   23 batch     0
# Epoch   23 batch    50
# [ 53.7203331] [54]
# Epoch   23 val.cost 0.000036 val.err 5.42% best
# Epoch   24 batch     0
# Epoch   24 batch    50
# [ 51.03472519] [52]
# Epoch   24 val.cost 0.000035 val.err 5.29% best
# Epoch   25 batch     0
# Epoch   25 batch    50
# [ 33.81503677] [0]
# Epoch   25 val.cost 0.000034 val.err 5.17% best
# Epoch   26 batch     0
# Epoch   26 batch    50
# [ 75.52754211] [76]
# Epoch   26 val.cost 0.000033 val.err 5.06% best
# Epoch   27 batch     0
# Epoch   27 batch    50
# [ 38.79951859] [40]
# Epoch   27 val.cost 0.000032 val.err 4.97% best
# Epoch   28 batch     0
# Epoch   28 batch    50
# [ 38.16048813] [42]
# Epoch   28 val.cost 0.000032 val.err 4.89% best
# Epoch   29 batch     0
# Epoch   29 batch    50
# [ 81.78384399] [78]
# Epoch   29 val.cost 0.000031 val.err 4.81% best
# Epoch   30 batch     0
# Epoch   30 batch    50
# [ 59.27430725] [62]
# Epoch   30 val.cost 0.000031 val.err 4.74% best
# Epoch   31 batch     0
# Epoch   31 batch    50
# [ 57.27708435] [58]
# Epoch   31 val.cost 0.000030 val.err 4.67% best
# Epoch   32 batch     0
# Epoch   32 batch    50
# [ 59.96237564] [62]
# Epoch   32 val.cost 0.000030 val.err 4.62% best
# Epoch   33 batch     0
# Epoch   33 batch    50
# [ 52.42701721] [53]
# Epoch   33 val.cost 0.000030 val.err 4.58% best
# Epoch   34 batch     0
# Epoch   34 batch    50
# [ 72.6371994] [73]
# Epoch   34 val.cost 0.000029 val.err 4.53% best
# Epoch   35 batch     0
# Epoch   35 batch    50
# [ 69.17809296] [67]
# Epoch   35 val.cost 0.000029 val.err 4.49% best
# Epoch   36 batch     0
# Epoch   36 batch    50
# [ 64.15021515] [62]
# Epoch   36 val.cost 0.000029 val.err 4.45% best
# Epoch   37 batch     0
# Epoch   37 batch    50
# [ 28.61995316] [26]
# Epoch   37 val.cost 0.000029 val.err 4.41% best
# Epoch   38 batch     0
# Epoch   38 batch    50
# [ 47.34746933] [45]
# Epoch   38 val.cost 0.000029 val.err 4.38% best
# Epoch   39 batch     0
# Epoch   39 batch    50
# [ 65.41376495] [69]
# Epoch   39 val.cost 0.000029 val.err 4.34% best
# Epoch   40 batch     0
# Epoch   40 batch    50
# [ 88.07698059] [88]
# Epoch   40 val.cost 0.000029 val.err 4.31% best
# Epoch   41 batch     0
# Epoch   41 batch    50
# [ 37.81027603] [39]
# Epoch   41 val.cost 0.000028 val.err 4.28% best
# Epoch   42 batch     0
# Epoch   42 batch    50
# [ 47.799366] [47]
# Epoch   42 val.cost 0.000028 val.err 4.25% best
# Epoch   43 batch     0
# Epoch   43 batch    50
# [ 91.31735229] [94]
# Epoch   43 val.cost 0.000028 val.err 4.22% best
# Epoch   44 batch     0
# Epoch   44 batch    50
# [ 28.16259384] [28]
# Epoch   44 val.cost 0.000028 val.err 4.21% best
# Epoch   45 batch     0
# Epoch   45 batch    50
# [ 70.51131439] [73]
# Epoch   45 val.cost 0.000028 val.err 4.18% best
# Epoch   46 batch     0
# Epoch   46 batch    50
# [ 49.60417175] [49]
# Epoch   46 val.cost 0.000028 val.err 4.16% best
# Epoch   47 batch     0
# Epoch   47 batch    50
# [ 69.90969849] [70]
# Epoch   47 val.cost 0.000028 val.err 4.13% best
# Epoch   48 batch     0
# Epoch   48 batch    50
# [ 78.15494537] [79]
# Epoch   48 val.cost 0.000028 val.err 4.11% best
# Epoch   49 batch     0
# Epoch   49 batch    50
# [ 66.02855682] [68]
# Epoch   49 val.cost 0.000028 val.err 4.08% best
# Epoch   50 batch     0
# Epoch   50 batch    50
# [ 67.57170105] [67]
# Epoch   50 val.cost 0.000028 val.err 4.06% best
# Epoch   51 batch     0
# Epoch   51 batch    50
# [ 95.14746094] [98]
# Epoch   51 val.cost 0.000028 val.err 4.05% best
# Epoch   52 batch     0
# Epoch   52 batch    50
# [ 74.27328491] [77]
# Epoch   52 val.cost 0.000028 val.err 4.03% best
# Epoch   53 batch     0
# Epoch   53 batch    50
# [ 70.87538147] [72]
# Epoch   53 val.cost 0.000029 val.err 4.02% best
# Epoch   54 batch     0
# Epoch   54 batch    50
# [ 40.08381653] [40]
# Epoch   54 val.cost 0.000029 val.err 4.02% best
# Epoch   55 batch     0
# Epoch   55 batch    50
# [ 55.37422943] [54]
# Epoch   55 val.cost 0.000029 val.err 4.00% best
# Epoch   56 batch     0
# Epoch   56 batch    50
# [ 56.96001816] [55]
# Epoch   56 val.cost 0.000029 val.err 3.99% best
# Epoch   57 batch     0
# Epoch   57 batch    50
# [ 40.85072327] [40]
# Epoch   57 val.cost 0.000029 val.err 3.98% best
# Epoch   58 batch     0
# Epoch   58 batch    50
# [ 23.62120247] [27]
# Epoch   58 val.cost 0.000029 val.err 3.97% best
# Epoch   59 batch     0
# Epoch   59 batch    50
# [ 57.63666916] [58]
# Epoch   59 val.cost 0.000029 val.err 3.96% best
# Epoch   60 batch     0
# Epoch   60 batch    50
# [ 72.59165192] [75]
# Epoch   60 val.cost 0.000029 val.err 3.95% best
# Epoch   61 batch     0
# Epoch   61 batch    50
# [ 42.2928772] [41]
# Epoch   61 val.cost 0.000029 val.err 3.94% best
# Epoch   62 batch     0
# Epoch   62 batch    50
# [ 60.1906395] [60]
# Epoch   62 val.cost 0.000029 val.err 3.94% best
# Epoch   63 batch     0
# Epoch   63 batch    50
# [ 56.45038986] [59]
# Epoch   63 val.cost 0.000029 val.err 3.93% best
# Epoch   64 batch     0
# Epoch   64 batch    50
# [ 23.31087685] [24]
# Epoch   64 val.cost 0.000029 val.err 3.92% best
# Epoch   65 batch     0
# Epoch   65 batch    50
# [ 78.36482239] [76]
# Epoch   65 val.cost 0.000029 val.err 3.91% best
# Epoch   66 batch     0
# Epoch   66 batch    50
# [ 42.84790421] [43]
# Epoch   66 val.cost 0.000029 val.err 3.91% best
# Epoch   67 batch     0
# Epoch   67 batch    50
# [ 50.07147598] [51]
# Epoch   67 val.cost 0.000029 val.err 3.90% best
# Epoch   68 batch     0
# Epoch   68 batch    50
# [ 49.21495056] [49]
# Epoch   68 val.cost 0.000029 val.err 3.90% best
# Epoch   69 batch     0
# Epoch   69 batch    50
# [ 48.02199173] [48]
# Epoch   69 val.cost 0.000029 val.err 3.89% best
# Epoch   70 batch     0
# Epoch   70 batch    50
# [ 75.67427826] [77]
# Epoch   70 val.cost 0.000029 val.err 3.88% best
# Epoch   71 batch     0
# Epoch   71 batch    50
# [ 66.70109558] [67]
# Epoch   71 val.cost 0.000029 val.err 3.89% stopping   1
# Epoch   72 batch     0
# Epoch   72 batch    50
# [ 45.0750351] [45]
# Epoch   72 val.cost 0.000029 val.err 3.89% stopping   2
# Epoch   73 batch     0
# Epoch   73 batch    50
# [ 73.79299927] [70]
# Epoch   73 val.cost 0.000029 val.err 3.88% best
# Epoch   74 batch     0
# Epoch   74 batch    50
# [ 56.28780746] [58]
# Epoch   74 val.cost 0.000029 val.err 3.87% best
# Epoch   75 batch     0
# Epoch   75 batch    50
# [ 36.38609314] [37]
# Epoch   75 val.cost 0.000029 val.err 3.88% stopping   1
# Epoch   76 batch     0
# Epoch   76 batch    50
# [ 44.10370255] [44]
# Epoch   76 val.cost 0.000029 val.err 3.87% best
# Epoch   77 batch     0
# Epoch   77 batch    50
# [ 42.45930862] [43]
# Epoch   77 val.cost 0.000029 val.err 3.87% stopping   1
# Epoch   78 batch     0
# Epoch   78 batch    50
# [ 52.77732086] [54]
# Epoch   78 val.cost 0.000029 val.err 3.86% best
# Epoch   79 batch     0
# Epoch   79 batch    50
# [ 72.52568054] [69]
# Epoch   79 val.cost 0.000029 val.err 3.86% best
# Epoch   80 batch     0
# Epoch   80 batch    50
# [ 44.21676254] [45]
# Epoch   80 val.cost 0.000029 val.err 3.86% best
# Epoch   81 batch     0
# Epoch   81 batch    50
# [ 64.88424683] [68]
# Epoch   81 val.cost 0.000029 val.err 3.85% best
# Epoch   82 batch     0
# Epoch   82 batch    50
# [ 73.11442566] [76]
# Epoch   82 val.cost 0.000029 val.err 3.85% best
# Epoch   83 batch     0
# Epoch   83 batch    50
# [ 32.35476303] [32]
# Epoch   83 val.cost 0.000029 val.err 3.85% best
# Epoch   84 batch     0
# Epoch   84 batch    50
# [ 40.50239182] [41]
# Epoch   84 val.cost 0.000029 val.err 3.85% best
# Epoch   85 batch     0
# Epoch   85 batch    50
# [ 40.78666306] [41]
# Epoch   85 val.cost 0.000029 val.err 3.84% best
# Epoch   86 batch     0
# Epoch   86 batch    50
# [ 39.75351334] [41]
# Epoch   86 val.cost 0.000029 val.err 3.84% best
# Epoch   87 batch     0
# Epoch   87 batch    50
# [ 54.03236771] [56]
# Epoch   87 val.cost 0.000029 val.err 3.83% best
# Epoch   88 batch     0
# Epoch   88 batch    50
# [ 64.12057495] [64]
# Epoch   88 val.cost 0.000029 val.err 3.83% best
# Epoch   89 batch     0
# Epoch   89 batch    50
# [ 53.5733757] [55]
# Epoch   89 val.cost 0.000029 val.err 3.83% best
# Epoch   90 batch     0
# Epoch   90 batch    50
# [ 22.04790115] [31]
# Epoch   90 val.cost 0.000029 val.err 3.82% best
# Epoch   91 batch     0
# Epoch   91 batch    50
# [ 28.45502853] [29]
# Epoch   91 val.cost 0.000029 val.err 3.82% best
# Epoch   92 batch     0
# Epoch   92 batch    50
# [ 51.05498123] [48]
# Epoch   92 val.cost 0.000029 val.err 3.81% best
# Epoch   93 batch     0
# Epoch   93 batch    50
# [ 22.48482513] [23]
# Epoch   93 val.cost 0.000029 val.err 3.80% best
# Epoch   94 batch     0
# Epoch   94 batch    50
# [ 50.85481644] [51]
# Epoch   94 val.cost 0.000029 val.err 3.80% best
# Epoch   95 batch     0
# Epoch   95 batch    50
# [ 52.17904663] [55]
# Epoch   95 val.cost 0.000029 val.err 3.80% best
# Epoch   96 batch     0
# Epoch   96 batch    50
# [ 26.94841957] [26]
# Epoch   96 val.cost 0.000029 val.err 3.79% best
# Epoch   97 batch     0
# Epoch   97 batch    50
# [ 22.04510498] [22]
# Epoch   97 val.cost 0.000029 val.err 3.79% best
# Epoch   98 batch     0
# Epoch   98 batch    50
# [ 62.67787552] [62]
# Epoch   98 val.cost 0.000029 val.err 3.78% best
# Epoch   99 batch     0
# Epoch   99 batch    50
# [ 40.39565659] [41]
# Epoch   99 val.cost 0.000029 val.err 3.78% best
# best model saved to: ./best_model/model_20180616_193816
# Total time: 887.584641
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b'./final_model_5/area_1/saved_model.pb'
# area 2
# train len = 2372009
# test len = 701557
# model will be exported in ./final_model_5/area_2/
# now= 20180616_195312
# Total batch: 237
# Epoch    0 batch     0
# Epoch    0 batch    50
# Epoch    0 batch   100
# Epoch    0 batch   150
# Epoch    0 batch   200
# [ 63.19855881] [62]
# Epoch    0 val.cost 0.000963 val.err 67.26% best
# Epoch    1 batch     0
# Epoch    1 batch    50
# Epoch    1 batch   100
# Epoch    1 batch   150
# Epoch    1 batch   200
# [ 51.36513519] [36]
# Epoch    1 val.cost 0.000485 val.err 41.68% best
# Epoch    2 batch     0
# Epoch    2 batch    50
# Epoch    2 batch   100
# Epoch    2 batch   150
# Epoch    2 batch   200
# [ 44.94075012] [5]
# Epoch    2 val.cost 0.000328 val.err 31.10% best
# Epoch    3 batch     0
# Epoch    3 batch    50
# Epoch    3 batch   100
# Epoch    3 batch   150
# Epoch    3 batch   200
# [ 40.84854507] [34]
# Epoch    3 val.cost 0.000251 val.err 25.49% best
# Epoch    4 batch     0
# Epoch    4 batch    50
# Epoch    4 batch   100
# Epoch    4 batch   150
# Epoch    4 batch   200
# [ 37.77275467] [8]
# Epoch    4 val.cost 0.000208 val.err 22.06% best
# Epoch    5 batch     0
# Epoch    5 batch    50
# Epoch    5 batch   100
# Epoch    5 batch   150
# Epoch    5 batch   200
# [ 35.22938156] [5]
# Epoch    5 val.cost 0.000181 val.err 19.75% best
# Epoch    6 batch     0
# Epoch    6 batch    50
# Epoch    6 batch   100
# Epoch    6 batch   150
# Epoch    6 batch   200
# [ 34.2118721] [35]
# Epoch    6 val.cost 0.000163 val.err 18.08% best
# Epoch    7 batch     0
# Epoch    7 batch    50
# Epoch    7 batch   100
# Epoch    7 batch   150
# Epoch    7 batch   200
# [ 44.84080887] [44]
# Epoch    7 val.cost 0.000150 val.err 16.78% best
# Epoch    8 batch     0
# Epoch    8 batch    50
# Epoch    8 batch   100
# Epoch    8 batch   150
# Epoch    8 batch   200
# [ 30.25991821] [7]
# Epoch    8 val.cost 0.000141 val.err 15.80% best
# Epoch    9 batch     0
# Epoch    9 batch    50
# Epoch    9 batch   100
# Epoch    9 batch   150
# Epoch    9 batch   200
# [ 40.38514328] [41]
# Epoch    9 val.cost 0.000134 val.err 15.04% best
# Epoch   10 batch     0
# Epoch   10 batch    50
# Epoch   10 batch   100
# Epoch   10 batch   150
# Epoch   10 batch   200
# [ 28.76618195] [29]
# Epoch   10 val.cost 0.000130 val.err 14.44% best
# Epoch   11 batch     0
# Epoch   11 batch    50
# Epoch   11 batch   100
# Epoch   11 batch   150
# Epoch   11 batch   200
# [ 27.26840591] [45]
# Epoch   11 val.cost 0.000127 val.err 13.96% best
# Epoch   12 batch     0
# Epoch   12 batch    50
# Epoch   12 batch   100
# Epoch   12 batch   150
# Epoch   12 batch   200
# [ 42.32262802] [44]
# Epoch   12 val.cost 0.000124 val.err 13.59% best
# Epoch   13 batch     0
# Epoch   13 batch    50
# Epoch   13 batch   100
# Epoch   13 batch   150
# Epoch   13 batch   200
# [ 26.61214828] [26]
# Epoch   13 val.cost 0.000122 val.err 13.28% best
# Epoch   14 batch     0
# Epoch   14 batch    50
# Epoch   14 batch   100
# Epoch   14 batch   150
# Epoch   14 batch   200
# [ 35.00131989] [36]
# Epoch   14 val.cost 0.000121 val.err 13.04% best
# Epoch   15 batch     0
# Epoch   15 batch    50
# Epoch   15 batch   100
# Epoch   15 batch   150
# Epoch   15 batch   200
# [ 24.94336891] [4]
# Epoch   15 val.cost 0.000120 val.err 12.84% best
# Epoch   16 batch     0
# Epoch   16 batch    50
# Epoch   16 batch   100
# Epoch   16 batch   150
# Epoch   16 batch   200
# [ 54.33332443] [55]
# Epoch   16 val.cost 0.000119 val.err 12.65% best
# Epoch   17 batch     0
# Epoch   17 batch    50
# Epoch   17 batch   100
# Epoch   17 batch   150
# Epoch   17 batch   200
# [ 24.23577309] [14]
# Epoch   17 val.cost 0.000118 val.err 12.51% best
# Epoch   18 batch     0
# Epoch   18 batch    50
# Epoch   18 batch   100
# Epoch   18 batch   150
# Epoch   18 batch   200
# [ 62.11783981] [63]
# Epoch   18 val.cost 0.000117 val.err 12.40% best
# Epoch   19 batch     0
# Epoch   19 batch    50
# Epoch   19 batch   100
# Epoch   19 batch   150
# Epoch   19 batch   200
# [ 52.37692642] [52]
# Epoch   19 val.cost 0.000117 val.err 12.31% best
# Epoch   20 batch     0
# Epoch   20 batch    50
# Epoch   20 batch   100
# Epoch   20 batch   150
# Epoch   20 batch   200
# [ 55.50601196] [54]
# Epoch   20 val.cost 0.000116 val.err 12.23% best
# Epoch   21 batch     0
# Epoch   21 batch    50
# Epoch   21 batch   100
# Epoch   21 batch   150
# Epoch   21 batch   200
# [ 41.92850494] [42]
# Epoch   21 val.cost 0.000115 val.err 12.17% best
# Epoch   22 batch     0
# Epoch   22 batch    50
# Epoch   22 batch   100
# Epoch   22 batch   150
# Epoch   22 batch   200
# [ 57.09001923] [57]
# Epoch   22 val.cost 0.000115 val.err 12.12% best
# Epoch   23 batch     0
# Epoch   23 batch    50
# Epoch   23 batch   100
# Epoch   23 batch   150
# Epoch   23 batch   200
# [ 94.5148468] [94]
# Epoch   23 val.cost 0.000114 val.err 12.08% best
# Epoch   24 batch     0
# Epoch   24 batch    50
# Epoch   24 batch   100
# Epoch   24 batch   150
# Epoch   24 batch   200
# [ 23.39192772] [9]
# Epoch   24 val.cost 0.000114 val.err 12.05% best
# Epoch   25 batch     0
# Epoch   25 batch    50
# Epoch   25 batch   100
# Epoch   25 batch   150
# Epoch   25 batch   200
# [ 28.83854294] [28]
# Epoch   25 val.cost 0.000113 val.err 12.02% best
# Epoch   26 batch     0
# Epoch   26 batch    50
# Epoch   26 batch   100
# Epoch   26 batch   150
# Epoch   26 batch   200
# [ 23.56573296] [48]
# Epoch   26 val.cost 0.000113 val.err 11.99% best
# Epoch   27 batch     0
# Epoch   27 batch    50
# Epoch   27 batch   100
# Epoch   27 batch   150
# Epoch   27 batch   200
# [ 40.59961319] [41]
# Epoch   27 val.cost 0.000112 val.err 11.96% best
# Epoch   28 batch     0
# Epoch   28 batch    50
# Epoch   28 batch   100
# Epoch   28 batch   150
# Epoch   28 batch   200
# [ 28.86007118] [28]
# Epoch   28 val.cost 0.000111 val.err 11.92% best
# Epoch   29 batch     0
# Epoch   29 batch    50
# Epoch   29 batch   100
# Epoch   29 batch   150
# Epoch   29 batch   200
# [ 23.59274673] [22]
# Epoch   29 val.cost 0.000110 val.err 11.86% best
# Epoch   30 batch     0
# Epoch   30 batch    50
# Epoch   30 batch   100
# Epoch   30 batch   150
# Epoch   30 batch   200
# [ 51.51389313] [52]
# Epoch   30 val.cost 0.000105 val.err 11.67% best
# Epoch   31 batch     0
# Epoch   31 batch    50
# Epoch   31 batch   100
# Epoch   31 batch   150
# Epoch   31 batch   200
# [ 60.35956955] [59]
# Epoch   31 val.cost 0.000093 val.err 10.70% best
# Epoch   32 batch     0
# Epoch   32 batch    50
# Epoch   32 batch   100
# Epoch   32 batch   150
# Epoch   32 batch   200
# [ 27.0852375] [27]
# Epoch   32 val.cost 0.000084 val.err 9.60% best
# Epoch   33 batch     0
# Epoch   33 batch    50
# Epoch   33 batch   100
# Epoch   33 batch   150
# Epoch   33 batch   200
# [ 45.7101593] [45]
# Epoch   33 val.cost 0.000080 val.err 9.04% best
# Epoch   34 batch     0
# Epoch   34 batch    50
# Epoch   34 batch   100
# Epoch   34 batch   150
# Epoch   34 batch   200
# [ 15.73823166] [13]
# Epoch   34 val.cost 0.000078 val.err 8.68% best
# Epoch   35 batch     0
# Epoch   35 batch    50
# Epoch   35 batch   100
# Epoch   35 batch   150
# Epoch   35 batch   200
# [ 27.43053246] [29]
# Epoch   35 val.cost 0.000075 val.err 8.41% best
# Epoch   36 batch     0
# Epoch   36 batch    50
# Epoch   36 batch   100
# Epoch   36 batch   150
# Epoch   36 batch   200
# [ 38.38482285] [39]
# Epoch   36 val.cost 0.000073 val.err 8.20% best
# Epoch   37 batch     0
# Epoch   37 batch    50
# Epoch   37 batch   100
# Epoch   37 batch   150
# Epoch   37 batch   200
# [ 35.70819092] [37]
# Epoch   37 val.cost 0.000072 val.err 8.05% best
# Epoch   38 batch     0
# Epoch   38 batch    50
# Epoch   38 batch   100
# Epoch   38 batch   150
# Epoch   38 batch   200
# [ 13.73527718] [2]
# Epoch   38 val.cost 0.000070 val.err 7.86% best
# Epoch   39 batch     0
# Epoch   39 batch    50
# Epoch   39 batch   100
# Epoch   39 batch   150
# Epoch   39 batch   200
# [ 30.97146606] [15]
# Epoch   39 val.cost 0.000068 val.err 7.71% best
# Epoch   40 batch     0
# Epoch   40 batch    50
# Epoch   40 batch   100
# Epoch   40 batch   150
# Epoch   40 batch   200
# [ 53.0157814] [55]
# Epoch   40 val.cost 0.000067 val.err 7.60% best
# Epoch   41 batch     0
# Epoch   41 batch    50
# Epoch   41 batch   100
# Epoch   41 batch   150
# Epoch   41 batch   200
# [ 34.88784027] [36]
# Epoch   41 val.cost 0.000066 val.err 7.53% best
# Epoch   42 batch     0
# Epoch   42 batch    50
# Epoch   42 batch   100
# Epoch   42 batch   150
# Epoch   42 batch   200
# [ 23.84818459] [26]
# Epoch   42 val.cost 0.000065 val.err 7.44% best
# Epoch   43 batch     0
# Epoch   43 batch    50
# Epoch   43 batch   100
# Epoch   43 batch   150
# Epoch   43 batch   200
# [ 32.89377594] [34]
# Epoch   43 val.cost 0.000064 val.err 7.36% best
# Epoch   44 batch     0
# Epoch   44 batch    50
# Epoch   44 batch   100
# Epoch   44 batch   150
# Epoch   44 batch   200
# [ 48.27460098] [52]
# Epoch   44 val.cost 0.000063 val.err 7.30% best
# Epoch   45 batch     0
# Epoch   45 batch    50
# Epoch   45 batch   100
# Epoch   45 batch   150
# Epoch   45 batch   200
# [ 35.86801147] [43]
# Epoch   45 val.cost 0.000064 val.err 7.29% best
# Epoch   46 batch     0
# Epoch   46 batch    50
# Epoch   46 batch   100
# Epoch   46 batch   150
# Epoch   46 batch   200
# [ 38.62417221] [38]
# Epoch   46 val.cost 0.000063 val.err 7.19% best
# Epoch   47 batch     0
# Epoch   47 batch    50
# Epoch   47 batch   100
# Epoch   47 batch   150
# Epoch   47 batch   200
# [ 53.35906982] [53]
# Epoch   47 val.cost 0.000062 val.err 7.14% best
# Epoch   48 batch     0
# Epoch   48 batch    50
# Epoch   48 batch   100
# Epoch   48 batch   150
# Epoch   48 batch   200
# [ 8.62001228] [3]
# Epoch   48 val.cost 0.000062 val.err 7.14% best
# Epoch   49 batch     0
# Epoch   49 batch    50
# Epoch   49 batch   100
# Epoch   49 batch   150
# Epoch   49 batch   200
# [ 45.66230774] [45]
# Epoch   49 val.cost 0.000061 val.err 7.09% best
# Epoch   50 batch     0
# Epoch   50 batch    50
# Epoch   50 batch   100
# Epoch   50 batch   150
# Epoch   50 batch   200
# [ 20.55077744] [21]
# Epoch   50 val.cost 0.000061 val.err 7.04% best
# Epoch   51 batch     0
# Epoch   51 batch    50
# Epoch   51 batch   100
# Epoch   51 batch   150
# Epoch   51 batch   200
# [ 45.65697861] [46]
# Epoch   51 val.cost 0.000062 val.err 6.99% best
# Epoch   52 batch     0
# Epoch   52 batch    50
# Epoch   52 batch   100
# Epoch   52 batch   150
# Epoch   52 batch   200
# [ 7.60571098] [5]
# Epoch   52 val.cost 0.000062 val.err 6.98% best
# Epoch   53 batch     0
# Epoch   53 batch    50
# Epoch   53 batch   100
# Epoch   53 batch   150
# Epoch   53 batch   200
# [ 37.63331604] [39]
# Epoch   53 val.cost 0.000061 val.err 6.95% best
# Epoch   54 batch     0
# Epoch   54 batch    50
# Epoch   54 batch   100
# Epoch   54 batch   150
# Epoch   54 batch   200
# [ 42.46858597] [43]
# Epoch   54 val.cost 0.000061 val.err 6.94% best
# Epoch   55 batch     0
# Epoch   55 batch    50
# Epoch   55 batch   100
# Epoch   55 batch   150
# Epoch   55 batch   200
# [ 44.37436676] [44]
# Epoch   55 val.cost 0.000061 val.err 6.94% best
# Epoch   56 batch     0
# Epoch   56 batch    50
# Epoch   56 batch   100
# Epoch   56 batch   150
# Epoch   56 batch   200
# [ 40.3255043] [41]
# Epoch   56 val.cost 0.000061 val.err 6.86% best
# Epoch   57 batch     0
# Epoch   57 batch    50
# Epoch   57 batch   100
# Epoch   57 batch   150
# Epoch   57 batch   200
# [ 13.85259533] [14]
# Epoch   57 val.cost 0.000060 val.err 6.87% stopping   1
# Epoch   58 batch     0
# Epoch   58 batch    50
# Epoch   58 batch   100
# Epoch   58 batch   150
# Epoch   58 batch   200
# [ 52.78332901] [4]
# Epoch   58 val.cost 0.000060 val.err 6.88% stopping   2
# Epoch   59 batch     0
# Epoch   59 batch    50
# Epoch   59 batch   100
# Epoch   59 batch   150
# Epoch   59 batch   200
# [ 38.70087051] [36]
# Epoch   59 val.cost 0.000060 val.err 6.86% best
# Epoch   60 batch     0
# Epoch   60 batch    50
# Epoch   60 batch   100
# Epoch   60 batch   150
# Epoch   60 batch   200
# [ 16.35589218] [16]
# Epoch   60 val.cost 0.000060 val.err 6.84% best
# Epoch   61 batch     0
# Epoch   61 batch    50
# Epoch   61 batch   100
# Epoch   61 batch   150
# Epoch   61 batch   200
# [ 52.15970612] [51]
# Epoch   61 val.cost 0.000060 val.err 6.82% best
# Epoch   62 batch     0
# Epoch   62 batch    50
# Epoch   62 batch   100
# Epoch   62 batch   150
# Epoch   62 batch   200
# [ 43.99816895] [45]
# Epoch   62 val.cost 0.000059 val.err 6.83% stopping   1
# Epoch   63 batch     0
# Epoch   63 batch    50
# Epoch   63 batch   100
# Epoch   63 batch   150
# Epoch   63 batch   200
# [ 54.20221329] [55]
# Epoch   63 val.cost 0.000060 val.err 6.84% stopping   2
# Epoch   64 batch     0
# Epoch   64 batch    50
# Epoch   64 batch   100
# Epoch   64 batch   150
# Epoch   64 batch   200
# [ 33.58365631] [34]
# Epoch   64 val.cost 0.000060 val.err 6.84% stopping   3
# Epoch   65 batch     0
# Epoch   65 batch    50
# Epoch   65 batch   100
# Epoch   65 batch   150
# Epoch   65 batch   200
# [ 42.91247559] [45]
# Epoch   65 val.cost 0.000060 val.err 6.81% best
# Epoch   66 batch     0
# Epoch   66 batch    50
# Epoch   66 batch   100
# Epoch   66 batch   150
# Epoch   66 batch   200
# [ 36.93584061] [37]
# Epoch   66 val.cost 0.000060 val.err 6.83% stopping   1
# Epoch   67 batch     0
# Epoch   67 batch    50
# Epoch   67 batch   100
# Epoch   67 batch   150
# Epoch   67 batch   200
# [ 27.76171112] [27]
# Epoch   67 val.cost 0.000060 val.err 6.82% stopping   2
# Epoch   68 batch     0
# Epoch   68 batch    50
# Epoch   68 batch   100
# Epoch   68 batch   150
# Epoch   68 batch   200
# [ 19.79916] [20]
# Epoch   68 val.cost 0.000061 val.err 6.79% best
# Epoch   69 batch     0
# Epoch   69 batch    50
# Epoch   69 batch   100
# Epoch   69 batch   150
# Epoch   69 batch   200
# [ 39.58586884] [41]
# Epoch   69 val.cost 0.000060 val.err 6.80% stopping   1
# Epoch   70 batch     0
# Epoch   70 batch    50
# Epoch   70 batch   100
# Epoch   70 batch   150
# Epoch   70 batch   200
# [ 46.44771194] [47]
# Epoch   70 val.cost 0.000061 val.err 6.83% stopping   2
# Epoch   71 batch     0
# Epoch   71 batch    50
# Epoch   71 batch   100
# Epoch   71 batch   150
# Epoch   71 batch   200
# [ 9.90713787] [10]
# Epoch   71 val.cost 0.000061 val.err 6.87% stopping   3
# Epoch   72 batch     0
# Epoch   72 batch    50
# Epoch   72 batch   100
# Epoch   72 batch   150
# Epoch   72 batch   200
# [ 41.44612122] [42]
# Epoch   72 val.cost 0.000061 val.err 6.94% stopping   4
# Epoch   73 batch     0
# Epoch   73 batch    50
# Epoch   73 batch   100
# Epoch   73 batch   150
# Epoch   73 batch   200
# [ 6.17535353] [8]
# Epoch   73 val.cost 0.000061 val.err 6.91% stopping   5
# Epoch   74 batch     0
# Epoch   74 batch    50
# Epoch   74 batch   100
# Epoch   74 batch   150
# Epoch   74 batch   200
# [ 42.33932877] [43]
# Epoch   74 val.cost 0.000061 val.err 6.88% stopping   6
# Epoch   75 batch     0
# Epoch   75 batch    50
# Epoch   75 batch   100
# Epoch   75 batch   150
# Epoch   75 batch   200
# [ 23.57967377] [23]
# Epoch   75 val.cost 0.000062 val.err 6.96% stopping   7
# Epoch   76 batch     0
# Epoch   76 batch    50
# Epoch   76 batch   100
# Epoch   76 batch   150
# Epoch   76 batch   200
# [ 38.91230392] [39]
# Epoch   76 val.cost 0.000062 val.err 6.94% stopping   8
# Epoch   77 batch     0
# Epoch   77 batch    50
# Epoch   77 batch   100
# Epoch   77 batch   150
# Epoch   77 batch   200
# [ 39.26456451] [40]
# Epoch   77 val.cost 0.000062 val.err 6.93% stopping   9
# Epoch   78 batch     0
# Epoch   78 batch    50
# Epoch   78 batch   100
# Epoch   78 batch   150
# Epoch   78 batch   200
# [ 79.38565826] [79]
# Epoch   78 val.cost 0.000062 val.err 6.98% stopping  10
# Early stopping triggered: Step:      18686, val.err 6.98%
# best model saved to: ./best_model/model_20180616_195312
# Total time: 1720.42542
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b'./final_model_5/area_2/saved_model.pb'
# area 3
# train len = 1221305
# test len = 308679
# model will be exported in ./final_model_5/area_3/
# now= 20180616_202200
# Total batch: 122
# Epoch    0 batch     0
# Epoch    0 batch    50
# Epoch    0 batch   100
# [ 98.79389191] [47]
# Epoch    0 val.cost 0.005198 val.err 206.66% best
# Epoch    1 batch     0
# Epoch    1 batch    50
# Epoch    1 batch   100
# [ 72.40768433] [12]
# Epoch    1 val.cost 0.002370 val.err 126.30% best
# Epoch    2 batch     0
# Epoch    2 batch    50
# Epoch    2 batch   100
# [ 58.86245346] [41]
# Epoch    2 val.cost 0.001446 val.err 87.00% best
# Epoch    3 batch     0
# Epoch    3 batch    50
# Epoch    3 batch   100
# [ 50.72493362] [25]
# Epoch    3 val.cost 0.001063 val.err 66.62% best
# Epoch    4 batch     0
# Epoch    4 batch    50
# Epoch    4 batch   100
# [ 45.25900269] [5]
# Epoch    4 val.cost 0.000875 val.err 55.60% best
# Epoch    5 batch     0
# Epoch    5 batch    50
# Epoch    5 batch   100
# [ 41.37930679] [53]
# Epoch    5 val.cost 0.000773 val.err 49.43% best
# Epoch    6 batch     0
# Epoch    6 batch    50
# Epoch    6 batch   100
# [ 38.40287399] [23]
# Epoch    6 val.cost 0.000714 val.err 45.83% best
# Epoch    7 batch     0
# Epoch    7 batch    50
# Epoch    7 batch   100
# [ 36.12159348] [4]
# Epoch    7 val.cost 0.000678 val.err 43.63% best
# Epoch    8 batch     0
# Epoch    8 batch    50
# Epoch    8 batch   100
# [ 34.33000946] [2]
# Epoch    8 val.cost 0.000656 val.err 42.29% best
# Epoch    9 batch     0
# Epoch    9 batch    50
# Epoch    9 batch   100
# [ 39.66516495] [43]
# Epoch    9 val.cost 0.000642 val.err 41.40% best
# Epoch   10 batch     0
# Epoch   10 batch    50
# Epoch   10 batch   100
# [ 31.71156693] [44]
# Epoch   10 val.cost 0.000633 val.err 40.79% best
# Epoch   11 batch     0
# Epoch   11 batch    50
# Epoch   11 batch   100
# [ 30.8656311] [65]
# Epoch   11 val.cost 0.000628 val.err 40.36% best
# Epoch   12 batch     0
# Epoch   12 batch    50
# Epoch   12 batch   100
# [ 29.96846581] [17]
# Epoch   12 val.cost 0.000624 val.err 40.04% best
# Epoch   13 batch     0
# Epoch   13 batch    50
# Epoch   13 batch   100
# [ 55.68519974] [56]
# Epoch   13 val.cost 0.000622 val.err 39.79% best
# Epoch   14 batch     0
# Epoch   14 batch    50
# Epoch   14 batch   100
# [ 28.79758072] [51]
# Epoch   14 val.cost 0.000620 val.err 39.62% best
# Epoch   15 batch     0
# Epoch   15 batch    50
# Epoch   15 batch   100
# [ 28.35006714] [3]
# Epoch   15 val.cost 0.000619 val.err 39.46% best
# Epoch   16 batch     0
# Epoch   16 batch    50
# Epoch   16 batch   100
# [ 27.99413109] [25]
# Epoch   16 val.cost 0.000618 val.err 39.32% best
# Epoch   17 batch     0
# Epoch   17 batch    50
# Epoch   17 batch   100
# [ 27.78141975] [11]
# Epoch   17 val.cost 0.000618 val.err 39.23% best
# Epoch   18 batch     0
# Epoch   18 batch    50
# Epoch   18 batch   100
# [ 27.45625305] [15]
# Epoch   18 val.cost 0.000618 val.err 39.15% best
# Epoch   19 batch     0
# Epoch   19 batch    50
# Epoch   19 batch   100
# [ 27.33579254] [46]
# Epoch   19 val.cost 0.000618 val.err 39.09% best
# Epoch   20 batch     0
# Epoch   20 batch    50
# Epoch   20 batch   100
# [ 27.10849762] [18]
# Epoch   20 val.cost 0.000617 val.err 39.04% best
# Epoch   21 batch     0
# Epoch   21 batch    50
# Epoch   21 batch   100
# [ 27.01479149] [64]
# Epoch   21 val.cost 0.000617 val.err 39.00% best
# Epoch   22 batch     0
# Epoch   22 batch    50
# Epoch   22 batch   100
# [ 26.91564941] [29]
# Epoch   22 val.cost 0.000617 val.err 38.97% best
# Epoch   23 batch     0
# Epoch   23 batch    50
# Epoch   23 batch   100
# [ 26.92744827] [51]
# Epoch   23 val.cost 0.000617 val.err 38.94% best
# Epoch   24 batch     0
# Epoch   24 batch    50
# Epoch   24 batch   100
# [ 26.86893272] [9]
# Epoch   24 val.cost 0.000617 val.err 38.92% best
# Epoch   25 batch     0
# Epoch   25 batch    50
# Epoch   25 batch   100
# [ 26.7103405] [7]
# Epoch   25 val.cost 0.000617 val.err 38.91% best
# Epoch   26 batch     0
# Epoch   26 batch    50
# Epoch   26 batch   100
# [ 43.78787231] [44]
# Epoch   26 val.cost 0.000617 val.err 38.90% best
# Epoch   27 batch     0
# Epoch   27 batch    50
# Epoch   27 batch   100
# [ 26.76373672] [24]
# Epoch   27 val.cost 0.000617 val.err 38.89% best
# Epoch   28 batch     0
# Epoch   28 batch    50
# Epoch   28 batch   100
# [ 26.73711777] [41]
# Epoch   28 val.cost 0.000617 val.err 38.88% best
# Epoch   29 batch     0
# Epoch   29 batch    50
# Epoch   29 batch   100
# [ 26.6271534] [37]
# Epoch   29 val.cost 0.000616 val.err 38.88% stopping   1
# Epoch   30 batch     0
# Epoch   30 batch    50
# Epoch   30 batch   100
# [ 26.60823441] [58]
# Epoch   30 val.cost 0.000616 val.err 38.88% best
# Epoch   31 batch     0
# Epoch   31 batch    50
# Epoch   31 batch   100
# [ 26.600811] [43]
# Epoch   31 val.cost 0.000616 val.err 38.88% best
# Epoch   32 batch     0
# Epoch   32 batch    50
# Epoch   32 batch   100
# [ 26.67268944] [22]
# Epoch   32 val.cost 0.000616 val.err 38.87% best
# Epoch   33 batch     0
# Epoch   33 batch    50
# Epoch   33 batch   100
# [ 26.70751762] [17]
# Epoch   33 val.cost 0.000616 val.err 38.86% best
# Epoch   34 batch     0
# Epoch   34 batch    50
# Epoch   34 batch   100
# [ 26.60939217] [7]
# Epoch   34 val.cost 0.000616 val.err 38.86% best
# Epoch   35 batch     0
# Epoch   35 batch    50
# Epoch   35 batch   100
# [ 26.57568359] [9]
# Epoch   35 val.cost 0.000616 val.err 38.85% best
# Epoch   36 batch     0
# Epoch   36 batch    50
# Epoch   36 batch   100
# [ 44.91894913] [45]
# Epoch   36 val.cost 0.000616 val.err 38.85% best
# Epoch   37 batch     0
# Epoch   37 batch    50
# Epoch   37 batch   100
# [ 26.56438065] [29]
# Epoch   37 val.cost 0.000616 val.err 38.84% best
# Epoch   38 batch     0
# Epoch   38 batch    50
# Epoch   38 batch   100
# [ 26.56251717] [20]
# Epoch   38 val.cost 0.000616 val.err 38.85% stopping   1
# Epoch   39 batch     0
# Epoch   39 batch    50
# Epoch   39 batch   100
# [ 26.56208801] [15]
# Epoch   39 val.cost 0.000616 val.err 38.84% best
# Epoch   40 batch     0
# Epoch   40 batch    50
# Epoch   40 batch   100
# [ 26.55449867] [30]
# Epoch   40 val.cost 0.000616 val.err 38.85% stopping   1
# Epoch   41 batch     0
# Epoch   41 batch    50
# Epoch   41 batch   100
# [ 32.87979507] [33]
# Epoch   41 val.cost 0.000616 val.err 38.85% stopping   2
# Epoch   42 batch     0
# Epoch   42 batch    50
# Epoch   42 batch   100
# [ 26.54688454] [36]
# Epoch   42 val.cost 0.000616 val.err 38.84% best
# Epoch   43 batch     0
# Epoch   43 batch    50
# Epoch   43 batch   100
# [ 29.75590897] [30]
# Epoch   43 val.cost 0.000615 val.err 38.84% best
# Epoch   44 batch     0
# Epoch   44 batch    50
# Epoch   44 batch   100
# [ 26.53738213] [16]
# Epoch   44 val.cost 0.000615 val.err 38.83% best
# Epoch   45 batch     0
# Epoch   45 batch    50
# Epoch   45 batch   100
# [ 26.71883583] [15]
# Epoch   45 val.cost 0.000615 val.err 38.84% stopping   1
# Epoch   46 batch     0
# Epoch   46 batch    50
# Epoch   46 batch   100
# [ 26.52878761] [9]
# Epoch   46 val.cost 0.000615 val.err 38.82% best
# Epoch   47 batch     0
# Epoch   47 batch    50
# Epoch   47 batch   100
# [ 26.75205803] [57]
# Epoch   47 val.cost 0.000615 val.err 38.81% best
# Epoch   48 batch     0
# Epoch   48 batch    50
# Epoch   48 batch   100
# [ 26.74074936] [13]
# Epoch   48 val.cost 0.000615 val.err 38.80% best
# Epoch   49 batch     0
# Epoch   49 batch    50
# Epoch   49 batch   100
# [ 35.30292892] [35]
# Epoch   49 val.cost 0.000615 val.err 38.80% best
# Epoch   50 batch     0
# Epoch   50 batch    50
# Epoch   50 batch   100
# [ 26.7757473] [40]
# Epoch   50 val.cost 0.000615 val.err 38.79% best
# Epoch   51 batch     0
# Epoch   51 batch    50
# Epoch   51 batch   100
# [ 26.50329018] [15]
# Epoch   51 val.cost 0.000615 val.err 38.79% best
# Epoch   52 batch     0
# Epoch   52 batch    50
# Epoch   52 batch   100
# [ 26.48948479] [18]
# Epoch   52 val.cost 0.000615 val.err 38.78% best
# Epoch   53 batch     0
# Epoch   53 batch    50
# Epoch   53 batch   100
# [ 26.51789856] [58]
# Epoch   53 val.cost 0.000615 val.err 38.78% best
# Epoch   54 batch     0
# Epoch   54 batch    50
# Epoch   54 batch   100
# [ 26.45596695] [6]
# Epoch   54 val.cost 0.000615 val.err 38.76% best
# Epoch   55 batch     0
# Epoch   55 batch    50
# Epoch   55 batch   100
# [ 26.46699524] [0]
# Epoch   55 val.cost 0.000615 val.err 38.77% stopping   1
# Epoch   56 batch     0
# Epoch   56 batch    50
# Epoch   56 batch   100
# [ 26.3998909] [16]
# Epoch   56 val.cost 0.000615 val.err 38.76% stopping   2
# Epoch   57 batch     0
# Epoch   57 batch    50
# Epoch   57 batch   100
# [ 26.27414322] [44]
# Epoch   57 val.cost 0.000614 val.err 38.85% stopping   3
# Epoch   58 batch     0
# Epoch   58 batch    50
# Epoch   58 batch   100
# [ 25.2862072] [21]
# Epoch   58 val.cost 0.000614 val.err 38.76% stopping   4
# Epoch   59 batch     0
# Epoch   59 batch    50
# Epoch   59 batch   100
# [ 29.78009224] [21]
# Epoch   59 val.cost 0.000613 val.err 38.62% best
# Epoch   60 batch     0
# Epoch   60 batch    50
# Epoch   60 batch   100
# [ 26.86264992] [39]
# Epoch   60 val.cost 0.000611 val.err 38.32% best
# Epoch   61 batch     0
# Epoch   61 batch    50
# Epoch   61 batch   100
# [ 26.856287] [29]
# Epoch   61 val.cost 0.000608 val.err 37.94% best
# Epoch   62 batch     0
# Epoch   62 batch    50
# Epoch   62 batch   100
# [ 27.94854355] [27]
# Epoch   62 val.cost 0.000604 val.err 37.52% best
# Epoch   63 batch     0
# Epoch   63 batch    50
# Epoch   63 batch   100
# [ 27.26169205] [18]
# Epoch   63 val.cost 0.000600 val.err 37.14% best
# Epoch   64 batch     0
# Epoch   64 batch    50
# Epoch   64 batch   100
# [ 27.47867966] [11]
# Epoch   64 val.cost 0.000598 val.err 36.85% best
# Epoch   65 batch     0
# Epoch   65 batch    50
# Epoch   65 batch   100
# [ 27.48226166] [51]
# Epoch   65 val.cost 0.000596 val.err 36.70% best
# Epoch   66 batch     0
# Epoch   66 batch    50
# Epoch   66 batch   100
# [ 53.35494614] [52]
# Epoch   66 val.cost 0.000594 val.err 36.60% best
# Epoch   67 batch     0
# Epoch   67 batch    50
# Epoch   67 batch   100
# [ 25.53967857] [34]
# Epoch   67 val.cost 0.000593 val.err 36.45% best
# Epoch   68 batch     0
# Epoch   68 batch    50
# Epoch   68 batch   100
# [ 22.95047188] [21]
# Epoch   68 val.cost 0.000592 val.err 36.32% best
# Epoch   69 batch     0
# Epoch   69 batch    50
# Epoch   69 batch   100
# [ 30.02979088] [24]
# Epoch   69 val.cost 0.000591 val.err 36.22% best
# Epoch   70 batch     0
# Epoch   70 batch    50
# Epoch   70 batch   100
# [ 24.71175766] [31]
# Epoch   70 val.cost 0.000590 val.err 36.14% best
# Epoch   71 batch     0
# Epoch   71 batch    50
# Epoch   71 batch   100
# [ 28.25512695] [53]
# Epoch   71 val.cost 0.000590 val.err 36.06% best
# Epoch   72 batch     0
# Epoch   72 batch    50
# Epoch   72 batch   100
# [ 25.79595184] [8]
# Epoch   72 val.cost 0.000589 val.err 35.99% best
# Epoch   73 batch     0
# Epoch   73 batch    50
# Epoch   73 batch   100
# [ 24.90286064] [10]
# Epoch   73 val.cost 0.000589 val.err 35.94% best
# Epoch   74 batch     0
# Epoch   74 batch    50
# Epoch   74 batch   100
# [ 23.89648628] [0]
# Epoch   74 val.cost 0.000588 val.err 35.89% best
# Epoch   75 batch     0
# Epoch   75 batch    50
# Epoch   75 batch   100
# [ 23.28881645] [15]
# Epoch   75 val.cost 0.000588 val.err 35.82% best
# Epoch   76 batch     0
# Epoch   76 batch    50
# Epoch   76 batch   100
# [ 30.56764221] [29]
# Epoch   76 val.cost 0.000587 val.err 35.76% best
# Epoch   77 batch     0
# Epoch   77 batch    50
# Epoch   77 batch   100
# [ 32.13858795] [10]
# Epoch   77 val.cost 0.000587 val.err 35.73% best
# Epoch   78 batch     0
# Epoch   78 batch    50
# Epoch   78 batch   100
# [ 11.80531406] [6]
# Epoch   78 val.cost 0.000587 val.err 35.74% stopping   1
# Epoch   79 batch     0
# Epoch   79 batch    50
# Epoch   79 batch   100
# [ 26.55386543] [45]
# Epoch   79 val.cost 0.000587 val.err 35.73% stopping   2
# Epoch   80 batch     0
# Epoch   80 batch    50
# Epoch   80 batch   100
# [ 25.41323662] [41]
# Epoch   80 val.cost 0.000587 val.err 35.73% stopping   3
# Epoch   81 batch     0
# Epoch   81 batch    50
# Epoch   81 batch   100
# [ 23.50931358] [12]
# Epoch   81 val.cost 0.000587 val.err 35.77% stopping   4
# Epoch   82 batch     0
# Epoch   82 batch    50
# Epoch   82 batch   100
# [ 26.57713127] [57]
# Epoch   82 val.cost 0.000587 val.err 35.69% best
# Epoch   83 batch     0
# Epoch   83 batch    50
# Epoch   83 batch   100
# [ 29.78809166] [10]
# Epoch   83 val.cost 0.000587 val.err 35.71% stopping   1
# Epoch   84 batch     0
# Epoch   84 batch    50
# Epoch   84 batch   100
# [ 36.1255455] [40]
# Epoch   84 val.cost 0.000587 val.err 35.67% best
# Epoch   85 batch     0
# Epoch   85 batch    50
# Epoch   85 batch   100
# [ 21.22064972] [1]
# Epoch   85 val.cost 0.000587 val.err 35.67% best
# Epoch   86 batch     0
# Epoch   86 batch    50
# Epoch   86 batch   100
# [ 25.57877159] [40]
# Epoch   86 val.cost 0.000587 val.err 35.67% stopping   1
# Epoch   87 batch     0
# Epoch   87 batch    50
# Epoch   87 batch   100
# [ 27.34825325] [29]
# Epoch   87 val.cost 0.000587 val.err 35.64% best
# Epoch   88 batch     0
# Epoch   88 batch    50
# Epoch   88 batch   100
# [ 32.02719116] [32]
# Epoch   88 val.cost 0.000586 val.err 35.59% best
# Epoch   89 batch     0
# Epoch   89 batch    50
# Epoch   89 batch   100
# [ 12.32634258] [12]
# Epoch   89 val.cost 0.000586 val.err 35.59% best
# Epoch   90 batch     0
# Epoch   90 batch    50
# Epoch   90 batch   100
# [ 40.44307709] [49]
# Epoch   90 val.cost 0.000586 val.err 35.55% best
# Epoch   91 batch     0
# Epoch   91 batch    50
# Epoch   91 batch   100
# [ 23.21533203] [8]
# Epoch   91 val.cost 0.000586 val.err 35.55% stopping   1
# Epoch   92 batch     0
# Epoch   92 batch    50
# Epoch   92 batch   100
# [ 24.55683517] [18]
# Epoch   92 val.cost 0.000586 val.err 35.58% stopping   2
# Epoch   93 batch     0
# Epoch   93 batch    50
# Epoch   93 batch   100
# [ 26.68534279] [41]
# Epoch   93 val.cost 0.000586 val.err 35.57% stopping   3
# Epoch   94 batch     0
# 1384563  24.147  120.638 2017-02-28 23:59:56    23     True    1.0    1.0
# 1384564  22.646  120.326 2017-02-28 23:59:57    23     True    1.0    0.0
# 1384565  23.173  120.485 2017-02-28 23:59:57    23     True    1.0    1.0
# 1384566  35.169  128.057 2017-02-28 23:59:58    23    False    5.0    7.0
# 1384567  23.063  120.173 2017-02-28 23:59:58    23     True    1.0    1.0
# 1384568  25.068  121.627 2017-02-28 23:59:59    23     True    1.0    2.0
# 1384569  25.062  121.451 2017-02-28 23:59:59    23     True    1.0    2.0
#
#          area      idx
# 0         1.0        0
# 1         2.0        1
# 2         1.0        2
# 3         2.0        3
# 4         1.0        4
# 5         2.0        5
# 6         1.0        6
# 7         2.0        7
# 8         1.0        8
# 9         2.0        9
# 10        3.0       10
# 11        3.0       11
# 12        3.0       12
# 13        3.0       13
# 14        1.0       14
# 15        2.0       15
# 16        0.0       16
# 17        2.0       17
# 18        2.0       18
# 19        3.0       19
# 20        1.0       20
# 21        0.0       21
# 22        2.0       22
# 23        3.0       23
# 24        2.0       24
# 25        1.0       25
# 26        2.0       26
# 27        2.0       27
# 28        2.0       28
# 29        2.0       29
# ...       ...      ...
# 1384540   1.0  1384540
# 1384541   2.0  1384541
# 1384542   3.0  1384542
# 1384543   1.0  1384543
# 1384544   3.0  1384544
# 1384545   1.0  1384545
# 1384546   2.0  1384546
# 1384547   2.0  1384547
# 1384548   1.0  1384548
# 1384549   2.0  1384549
# 1384550   2.0  1384550
# 1384551   2.0  1384551
# 1384552   2.0  1384552
# 1384553   3.0  1384553
# 1384554   2.0  1384554
# 1384555   2.0  1384555
# 1384556   1.0  1384556
# 1384557   1.0  1384557
# 1384558   3.0  1384558
# 1384559   2.0  1384559
# 1384560   2.0  1384560
# 1384561   2.0  1384561
# 1384562   2.0  1384562
# 1384563   2.0  1384563
# 1384564   1.0  1384564
# 1384565   2.0  1384565
# 1384566   0.0  1384566
# 1384567   2.0  1384567
# 1384568   3.0  1384568
# 1384569   3.0  1384569
#
# [1384570 rows x 16 columns]

# %%
round_to_int = False
result_pd = pd.DataFrame({'PM2.5':[],'idx':[]})
for a in range(area_num):
#if True:
    #a = 0
    print('Area', a)
    tf.reset_default_graph()
    dft = df3[df3['area']==a]
    predict_values = np.zeros(len(dft))
    print(len(dft))
    df_X = dft[['Hour','PM10','PM1','Temperature','Humidity','lon','lat']]
    df_X = df_X.values
    df_Y = dft[['PM2.5']]
    df_Y = df_Y.values
    
    batch_size = 10000
    disp_log = 10
    n_batches = math.ceil(len(dft) / batch_size)
    with tf.Session(graph=tf.Graph()) as sess:
        tf.saved_model.loader.load(sess, ["tag"], export_dir + 'area_'+str(a)+"/")
        graph = tf.get_default_graph()
        X = graph.get_tensor_by_name("Input/X:0")
        is_training = graph.get_tensor_by_name("Input/is_training:0")
        predict = graph.get_tensor_by_name("Predict/predict:0")

        for i in range(n_batches):
            if i % disp_log == 0:
                print('batch',i)
            if i == n_batches - 1:
                X_batch = df_X[i*batch_size:]
                predict_batch = sess.run(predict, {is_training: False, X: X_batch})
                predict_values[i*batch_size:] = predict_batch[:,0]
            else:
                X_batch = df_X[i*batch_size:(i+1)*batch_size]
                predict_batch = sess.run(predict, {is_training: False, X: X_batch})
                predict_values[i*batch_size:(i+1)*batch_size] = predict_batch[:,0]


        if round_to_int:
            predict_values = [int(v) for v in predict_values]
    
    area_result = pd.DataFrame({'PM2.5':predict_values, 'idx':dft['idx']})
    result_pd = result_pd.append(area_result)
print('end')
# Out:
# Area 0
# 117992
# INFO:tensorflow:Restoring parameters from b'./final_model_5/area_0/variables\\variables'
# batch 0
# batch 10
# Area 1
# 244601
# INFO:tensorflow:Restoring parameters from b'./final_model_5/area_1/variables\\variables'
# batch 0
# batch 10
# batch 20
# Area 2
# 723014
# INFO:tensorflow:Restoring parameters from b'./final_model_5/area_2/variables\\variables'
# batch 0
# batch 10
# batch 20
# batch 30
# batch 40
# batch 50
# batch 60
# batch 70
# Area 3
# 298963
# INFO:tensorflow:Restoring parameters from b'./final_model_5/area_3/variables\\variables'
# batch 0
# batch 10
# batch 20
# end

# %%
result_pd.sort_values('idx')
# Out:
#               PM2.5        idx
# 0         57.822571        0.0
# 1         27.380884        1.0
# 2         49.965599        2.0
# 3         15.638891        3.0
# 4         35.877102        4.0
# 5         38.026768        5.0
# 6         54.426346        6.0
# 7         35.131573        7.0
# 8         55.201263        8.0
# 9         23.718853        9.0
# 10        22.985947       10.0
# 11        23.140894       11.0
# 12        27.420338       12.0
# 13        27.074144       13.0
# 14        43.636944       14.0
# 15        17.978514       15.0
# 16        33.297894       16.0
# 17        19.516792       17.0
# 18        22.462360       18.0
# 19        27.132883       19.0
# 20        54.331783       20.0
# 21        33.292522       21.0
# 22        15.567636       22.0
# 23        38.300541       23.0
# 24        36.322598       24.0
# 25        24.035503       25.0
# 26        11.339663       26.0
# 27        21.360859       27.0
# 28        20.095526       28.0
# 29        23.144279       29.0
# ...             ...        ...
# 1384540   75.879005  1384540.0
# 1384541   39.257938  1384541.0
# 1384542   27.015305  1384542.0
# 1384543  144.694458  1384543.0
# 1384544   40.680748  1384544.0
# 1384545   59.135551  1384545.0
# 1384546   54.269783  1384546.0
# 1384547   13.876659  1384547.0
# 1384548   46.691486  1384548.0
# 1384549   42.190399  1384549.0
# 1384550   21.121908  1384550.0
# 1384551   43.568546  1384551.0
# 1384552   46.892662  1384552.0
# 1384553   31.715088  1384553.0
# 1384554   43.974556  1384554.0
# 1384555   25.684372  1384555.0
# 1384556   63.371433  1384556.0
# 1384557   51.835438  1384557.0
# 1384558   26.987919  1384558.0
# 1384559   47.086552  1384559.0
# 1384560   27.805462  1384560.0
# 1384561   48.295334  1384561.0
# 1384562   41.678452  1384562.0
# 1384563   47.368774  1384563.0
# 1384564   60.269722  1384564.0
# 1384565   67.326851  1384565.0
# 1384566   33.297783  1384566.0
# 1384567   44.683998  1384567.0
# 1384568   16.322577  1384568.0
# 1384569   62.755680  1384569.0
#
# [1384570 rows x 2 columns]
