# %%
import pandas as pd
import os
#import matplotlib.pyplot as plt
import tensorflow as tf
from datetime import datetime
from tensorflow.contrib.layers import fully_connected, batch_norm
import math
import numpy as np
import random

# %%
df = pd.read_csv('./DL_final_project/DL_Taiwan_data/sinica/201701_Taiwan.csv',
                 usecols=['Date','Time','PM2.5','PM10','PM1','Temperature','Humidity','lon','lat'])
#把201701_Taiwan.csv的header的' lat',' lon'改成'lat','lon' (多了空格)
train_for_taiwan = True # filter out non-Taiwan
test_for_taiwan = False # filter out non-Taiwan
#len(df)

# %%
if train_for_taiwan:
    df = df[(df['lat']>= 21 )& (df['lat'] <= 27)&(df['lon']>=118)&(df['lon']<=122)]
df = df.assign(Timestamp = pd.to_datetime(df['Date']+' '+df['Time']))
df = df.assign(Hour = df['Timestamp'].dt.hour)

# %%
df_X = df[['Hour','PM10','PM1','Temperature','Humidity','lon','lat']]
df_X = df_X.values
df_Y = df[['PM2.5']]
df_Y = df_Y.values

# %%
root_logdir = "tf_logs"
batch_log_step = 50
early_stopping_epochs = 10

# %%
def dnn(X_1, y_1, X_2, y_2, X_3, y_3):
    tf.reset_default_graph()
    
    # check folder
    export_check_num = 1
    export_dir = './final_model/'
    while os.path.exists(export_dir):
        export_check_num += 1
        export_dir = './final_model_'+str(export_check_num)+'/'
    
    print("model will be exported in",export_dir)
    
    # logs
    start_time = datetime.now()
    now = start_time.strftime("%Y%m%d_%H%M%S")
    logdir = "./{}/run-{}".format(root_logdir, now)
    print("now=",now)
    
    # dnn graph defs
    n_input = 7
    n_epochs = 100
    n_hidden = [100,100,10]
    act_fn = tf.nn.sigmoid
    learning_rate = 0.001
    batch_normalization = False
    batch_size = 10000
    #batch_size = 1000 #小範圍測試用
    mult_bias = 1000

    # I/O
    with tf.name_scope("Input"):
        X = tf.placeholder(tf.float32, [None, n_input], name="X")
        is_training = tf.placeholder(tf.bool, shape=(), name="is_training")
    with tf.name_scope("Output"):
        y = tf.placeholder(tf.float32, [None, 1], name="y")
        y_biased = y/mult_bias
    
    # batch norm 
    he_init = tf.contrib.layers.variance_scaling_initializer()
    with tf.name_scope("BatchNormArgs"):
        bn_params = {
            'is_training': is_training,
            'decay': 0.99,
            'updates_collections': None,
            'scale': True
        }
    
    # DNN
    with tf.name_scope("DNN"):
        with tf.contrib.framework.arg_scope(
                [fully_connected],
                weights_initializer = he_init,
                normalizer_fn = batch_norm if batch_normalization else None,
                normalizer_params = bn_params if batch_normalization else None
                ):
            h1=fully_connected(X ,n_hidden[0],activation_fn=act_fn,scope="h1")
            h2=fully_connected(h1,n_hidden[1],activation_fn=act_fn,scope="h2")
            h3=fully_connected(h2,n_hidden[2],activation_fn=act_fn,scope="h3")
        logits=fully_connected(h3, 1, weights_initializer=he_init, activation_fn=act_fn,scope="out")
    
    with tf.name_scope("Cost"):
        #cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y), name="cost")
        cost = tf.losses.mean_squared_error(logits, y_biased)
    with tf.name_scope("AdamOptimizer"):
        optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate)
        minimizer = optimizer.minimize(cost)
    
    init = tf.global_variables_initializer()
    with tf.name_scope("ModelSaver"):
        saver = tf.train.Saver()
    
    with tf.name_scope("Predict"):
        predict = tf.multiply(logits, mult_bias, name="predict")
        
    with tf.name_scope("Error"):
        ave_of_batch_y = tf.reduce_mean(y_biased)
        error = tf.abs(logits - y_biased)/ave_of_batch_y
        relative_err = tf.reduce_mean(error)
    
    with tf.name_scope("Summaries-Train"):
        cost_summary = tf.summary.scalar('cost_function',cost)
        error_summary = tf.summary.scalar('relative_err',relative_err)
    with tf.name_scope("Summaries-Validation"):
        v_cost_summary = tf.summary.scalar('v_cost_function',cost)
        v_error_summary = tf.summary.scalar('v_relative_err',relative_err)
    file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())
    
    with tf.Session() as sess:
        sess.run(init)
        
        total_batch = len(X_1)//batch_size
        #total_batch = validation_idx_start//batch_size
        print("Total batch:",total_batch)
        #X_va, y_va = dfa_X[validation_idx_start:test_idx_start], dfa_Y[validation_idx_start:test_idx_start]
        X_va = X_2
        y_va = y_2
        X_test = X_3
        y_test = y_3
        
        best_va_err_triggered = False
        best_va_err = 0
        early_stopping_triggered = False
        stopping_epoch = 0
        step = 0
        save_path = ""
        best_save_path = ""
        
        perm = np.arange(len(X_1))
        np.random.shuffle(perm)
        X_t = X_1[perm]
        y_t = y_1[perm]
        
        for epoch in range(n_epochs):
            for batch in range(total_batch):
                X_ba = X_t[batch*batch_size: (batch+1)*batch_size]
                y_ba = y_t[batch*batch_size: (batch+1)*batch_size]
                _, c = sess.run([minimizer, cost], feed_dict = {is_training: True, X:X_ba, y:y_ba})
                
                if batch % batch_log_step == 0:
                    print("Epoch %4d batch %5d"%(epoch,batch))
                    cost_summary_str = cost_summary.eval(feed_dict={is_training:False, X:X_ba, y:y_ba})
                    step = epoch * total_batch + batch
                    file_writer.add_summary(cost_summary_str, step)
                    error_summary_str = error_summary.eval(feed_dict={is_training:False, X:X_ba, y:y_ba})
                    file_writer.add_summary(error_summary_str, step)
            
            save_path = saver.save(sess, "./checkpoint/model_"+now+".ckpt")
            va_err, va_cost = sess.run([relative_err, cost], feed_dict={is_training:False, X:X_va, y:y_va})
            va_l = sess.run(predict, feed_dict={is_training:False, X:X_va, y:y_va})
            rnd_result_idx = random.randint(0, len(X_va)-1)
            
            print(va_l[rnd_result_idx], y_va[rnd_result_idx]) # print 1st prediction result
            v_error_summary_str = v_error_summary.eval(feed_dict={is_training:False, X:X_va, y:y_va})
            file_writer.add_summary(v_error_summary_str, step)
            v_cost_summary_str = v_cost_summary.eval(feed_dict={is_training:False, X:X_va, y:y_va})
            file_writer.add_summary(v_cost_summary_str, step)
            print("Epoch %4d val.cost %3.6f val.err %3.2f%%"%(epoch,va_cost,va_err*100),end=" ")
            
            if best_va_err_triggered:
                if va_err < best_va_err:
                    print("best")
                    stopping_epoch = 0
                    best_va_err = va_err
                    
                    best_save_path = saver.save(sess, "./best_model/model_"+now)
                else:
                    stopping_epoch += 1
                    print("stopping %3d"%stopping_epoch)
                if stopping_epoch >= early_stopping_epochs:
                    early_stopping_triggered = True
                    print("Early stopping triggered: Step: %10d, val.err %3.2f%%"%(step, va_err*100))
            else:
                best_va_err = va_err
                best_va_err_triggered = True
                print("best")
                best_save_path = saver.save(sess, "./best_model/model_"+now)
            
            if early_stopping_triggered:
                break
        
        finish_time = datetime.now()
        print("best model saved to:", best_save_path)
        file_writer.close()
        elapse_time = finish_time - start_time
        total_seconds = elapse_time.total_seconds()
        print("Total time:", total_seconds)
        
        #X_test = dfa_X[test_idx_start:idx_end]
        #y_test = dfa_Y[test_idx_start:idx_end]
        saver.restore(sess, "./best_model/model_"+now)
        best_err = relative_err.eval({is_training: False, X: X_test, y: y_test})
        print("Test Err: %3.2f%%"%(best_err*100))
        
        
        builder = tf.saved_model.builder.SavedModelBuilder(export_dir)
        builder.add_meta_graph_and_variables(sess, ["tag"], signature_def_map= {
            "model": tf.saved_model.signature_def_utils.predict_signature_def(
                inputs= {"X": X, "is_training": is_training},
                outputs= {"predict": predict})
        })
        builder.save()
        
        """
        print("Predicting...")
        predict_values = sess.run(predict, feed_dict={is_training: False, X: X_w})
        print("Predict End")
        return predict_values
        """

# %%
# df2: validation
# df3: test
df_v = pd.read_csv('./DL_final_project/DL_Taiwan_data/sinica/201702_Taiwan.csv',
                 usecols=['Date','Time','PM2.5','PM10','PM1','Temperature','Humidity','lon','lat'])
test_idx_start = math.floor(len(df_v)*0.5)
df2 = df_v[:test_idx_start]
df3 = df_v[test_idx_start:]
if train_for_taiwan:
    df2 = df2[(df2['lat']>= 21 )& (df2['lat'] <= 27)&(df2['lon']>=118)&(df2['lon']<=122)]
if test_for_taiwan:
    df3 = df3[(df3['lat']>= 21 )& (df3['lat'] <= 27)&(df3['lon']>=118)&(df3['lon']<=122)]
df2 = df2.assign(Timestamp = pd.to_datetime(df2['Date']+' '+df2['Time']))
df3 = df3.assign(Timestamp = pd.to_datetime(df3['Date']+' '+df3['Time']))
df2 = df2.assign(Hour = df2['Timestamp'].dt.hour)
df3 = df3.assign(Hour = df3['Timestamp'].dt.hour)
df2_X = df2[['Hour','PM10','PM1','Temperature','Humidity','lon','lat']]
df2_y = df2[['PM2.5']]
df3_X = df3[['Hour','PM10','PM1','Temperature','Humidity','lon','lat']]
df3_y = df3[['PM2.5']]
df2_X = df2_X.values
df2_y = df2_y.values
df3_X = df3_X.values
df3_y = df3_y.values

# %%
dnn(df_X, df_Y, df2_X, df2_y, df3_X, df3_y)
# Out:
# model will be exported in ./final_model_3/
# now= 20180610_224109
# Total batch: 459
# Epoch    0 batch     0
# Epoch    0 batch    50
# Epoch    0 batch   100
# Epoch    0 batch   150
# Epoch    0 batch   200
# Epoch    0 batch   250
# Epoch    0 batch   300
# Epoch    0 batch   350
# Epoch    0 batch   400
# Epoch    0 batch   450
# [ 64.26473236] [32]
# Epoch    0 val.cost 0.001127 val.err 67.12% best
# Epoch    1 batch     0
# Epoch    1 batch    50
# Epoch    1 batch   100
# Epoch    1 batch   150
# Epoch    1 batch   200
# Epoch    1 batch   250
# Epoch    1 batch   300
# Epoch    1 batch   350
# Epoch    1 batch   400
# Epoch    1 batch   450
# [ 45.92326355] [53]
# Epoch    1 val.cost 0.000436 val.err 31.92% best
# Epoch    2 batch     0
# Epoch    2 batch    50
# Epoch    2 batch   100
# Epoch    2 batch   150
# Epoch    2 batch   200
# Epoch    2 batch   250
# Epoch    2 batch   300
# Epoch    2 batch   350
# Epoch    2 batch   400
# Epoch    2 batch   450
# [ 37.73513031] [46]
# Epoch    2 val.cost 0.000299 val.err 23.15% best
# Epoch    3 batch     0
# Epoch    3 batch    50
# Epoch    3 batch   100
# Epoch    3 batch   150
# Epoch    3 batch   200
# Epoch    3 batch   250
# Epoch    3 batch   300
# Epoch    3 batch   350
# Epoch    3 batch   400
# Epoch    3 batch   450
# [ 73.45629883] [70]
# Epoch    3 val.cost 0.000255 val.err 19.86% best
# Epoch    4 batch     0
# Epoch    4 batch    50
# Epoch    4 batch   100
# Epoch    4 batch   150
# Epoch    4 batch   200
# Epoch    4 batch   250
# Epoch    4 batch   300
# Epoch    4 batch   350
# Epoch    4 batch   400
# Epoch    4 batch   450
# [ 65.54608154] [59]
# Epoch    4 val.cost 0.000237 val.err 18.37% best
# Epoch    5 batch     0
# Epoch    5 batch    50
# Epoch    5 batch   100
# Epoch    5 batch   150
# Epoch    5 batch   200
# Epoch    5 batch   250
# Epoch    5 batch   300
# Epoch    5 batch   350
# Epoch    5 batch   400
# Epoch    5 batch   450
# [ 28.22981834] [20]
# Epoch    5 val.cost 0.000230 val.err 17.45% best
# Epoch    6 batch     0
# Epoch    6 batch    50
# Epoch    6 batch   100
# Epoch    6 batch   150
# Epoch    6 batch   200
# Epoch    6 batch   250
# Epoch    6 batch   300
# Epoch    6 batch   350
# Epoch    6 batch   400
# Epoch    6 batch   450
# [ 26.94881058] [31]
# Epoch    6 val.cost 0.000226 val.err 16.82% best
# Epoch    7 batch     0
# Epoch    7 batch    50
# Epoch    7 batch   100
# Epoch    7 batch   150
# Epoch    7 batch   200
# Epoch    7 batch   250
# Epoch    7 batch   300
# Epoch    7 batch   350
# Epoch    7 batch   400
# Epoch    7 batch   450
# [ 26.12231636] [30]
# Epoch    7 val.cost 0.000224 val.err 16.36% best
# Epoch    8 batch     0
# Epoch    8 batch    50
# Epoch    8 batch   100
# Epoch    8 batch   150
# Epoch    8 batch   200
# Epoch    8 batch   250
# Epoch    8 batch   300
# Epoch    8 batch   350
# Epoch    8 batch   400
# Epoch    8 batch   450
# [ 25.62190056] [1]
# Epoch    8 val.cost 0.000223 val.err 16.06% best
# Epoch    9 batch     0
# Epoch    9 batch    50
# Epoch    9 batch   100
# Epoch    9 batch   150
# Epoch    9 batch   200
# Epoch    9 batch   250
# Epoch    9 batch   300
# Epoch    9 batch   350
# Epoch    9 batch   400
# Epoch    9 batch   450
# [ 50.29872131] [49]
# Epoch    9 val.cost 0.000222 val.err 15.85% best
# Epoch   10 batch     0
# Epoch   10 batch    50
# Epoch   10 batch   100
# Epoch   10 batch   150
# Epoch   10 batch   200
# Epoch   10 batch   250
# Epoch   10 batch   300
# Epoch   10 batch   350
# Epoch   10 batch   400
# Epoch   10 batch   450
# [ 59.75780869] [61]
# Epoch   10 val.cost 0.000221 val.err 15.68% best
# Epoch   11 batch     0
# Epoch   11 batch    50
# Epoch   11 batch   100
# Epoch   11 batch   150
# Epoch   11 batch   200
# Epoch   11 batch   250
# Epoch   11 batch   300
# Epoch   11 batch   350
# Epoch   11 batch   400
# Epoch   11 batch   450
# [ 25.14525032] [48]
# Epoch   11 val.cost 0.000220 val.err 15.55% best
# Epoch   12 batch     0
# Epoch   12 batch    50
# Epoch   12 batch   100
# Epoch   12 batch   150
# Epoch   12 batch   200
# Epoch   12 batch   250
# Epoch   12 batch   300
# Epoch   12 batch   350
# Epoch   12 batch   400
# Epoch   12 batch   450
# [ 44.28793335] [45]
# Epoch   12 val.cost 0.000219 val.err 15.48% best
# Epoch   13 batch     0
# Epoch   13 batch    50
# Epoch   13 batch   100
# Epoch   13 batch   150
# Epoch   13 batch   200
# Epoch   13 batch   250
# Epoch   13 batch   300
# Epoch   13 batch   350
# Epoch   13 batch   400
# Epoch   13 batch   450
# [ 50.78902054] [51]
# Epoch   13 val.cost 0.000218 val.err 15.42% best
# Epoch   14 batch     0
# Epoch   14 batch    50
# Epoch   14 batch   100
# Epoch   14 batch   150
# Epoch   14 batch   200
# Epoch   14 batch   250
# Epoch   14 batch   300
# Epoch   14 batch   350
# Epoch   14 batch   400
# Epoch   14 batch   450
# [ 36.4103775] [37]
# Epoch   14 val.cost 0.000217 val.err 15.35% best
# Epoch   15 batch     0
# Epoch   15 batch    50
# Epoch   15 batch   100
# Epoch   15 batch   150
# Epoch   15 batch   200
# Epoch   15 batch   250
# Epoch   15 batch   300
# Epoch   15 batch   350
# Epoch   15 batch   400
# Epoch   15 batch   450
# [ 45.45756531] [45]
# Epoch   15 val.cost 0.000217 val.err 15.31% best
# Epoch   16 batch     0
# Epoch   16 batch    50
# Epoch   16 batch   100
# Epoch   16 batch   150
# Epoch   16 batch   200
# Epoch   16 batch   250
# Epoch   16 batch   300
# Epoch   16 batch   350
# Epoch   16 batch   400
# Epoch   16 batch   450
# [ 25.02202988] [5]
# Epoch   16 val.cost 0.000216 val.err 15.25% best
# Epoch   17 batch     0
# Epoch   17 batch    50
# Epoch   17 batch   100
# Epoch   17 batch   150
# Epoch   17 batch   200
# Epoch   17 batch   250
# Epoch   17 batch   300
# Epoch   17 batch   350
# Epoch   17 batch   400
# Epoch   17 batch   450
# [ 45.35253143] [45]
# Epoch   17 val.cost 0.000215 val.err 15.20% best
# Epoch   18 batch     0
# Epoch   18 batch    50
# Epoch   18 batch   100
# Epoch   18 batch   150
# Epoch   18 batch   200
# Epoch   18 batch   250
# Epoch   18 batch   300
# Epoch   18 batch   350
# Epoch   18 batch   400
# Epoch   18 batch   450
# [ 25.07095337] [24]
# Epoch   18 val.cost 0.000215 val.err 15.20% best
# Epoch   19 batch     0
# Epoch   19 batch    50
# Epoch   19 batch   100
# Epoch   19 batch   150
# Epoch   19 batch   200
# Epoch   19 batch   250
# Epoch   19 batch   300
# Epoch   19 batch   350
# Epoch   19 batch   400
# Epoch   19 batch   450
# [ 50.61787415] [53]
# Epoch   19 val.cost 0.000204 val.err 14.50% best
# Epoch   20 batch     0
# Epoch   20 batch    50
# Epoch   20 batch   100
# Epoch   20 batch   150
# Epoch   20 batch   200
# Epoch   20 batch   250
# Epoch   20 batch   300
# Epoch   20 batch   350
# Epoch   20 batch   400
# Epoch   20 batch   450
# [ 88.16661835] [89]
# Epoch   20 val.cost 0.000196 val.err 13.24% best
# Epoch   21 batch     0
# Epoch   21 batch    50
# Epoch   21 batch   100
# Epoch   21 batch   150
# Epoch   21 batch   200
# Epoch   21 batch   250
# Epoch   21 batch   300
# Epoch   21 batch   350
# Epoch   21 batch   400
# Epoch   21 batch   450
# [ 13.54875183] [6]
# Epoch   21 val.cost 0.000191 val.err 12.80% best
# Epoch   22 batch     0
# Epoch   22 batch    50
# Epoch   22 batch   100
# Epoch   22 batch   150
# Epoch   22 batch   200
# Epoch   22 batch   250
# Epoch   22 batch   300
# Epoch   22 batch   350
# Epoch   22 batch   400
# Epoch   22 batch   450
# [ 18.37234688] [20]
# Epoch   22 val.cost 0.000188 val.err 12.35% best
# Epoch   23 batch     0
# Epoch   23 batch    50
# Epoch   23 batch   100
# Epoch   23 batch   150
# Epoch   23 batch   200
# Epoch   23 batch   250
# Epoch   23 batch   300
# Epoch   23 batch   350
# Epoch   23 batch   400
# Epoch   23 batch   450
# [ 42.76703262] [43]
# Epoch   23 val.cost 0.000185 val.err 12.11% best
# Epoch   24 batch     0
# Epoch   24 batch    50
# Epoch   24 batch   100
# Epoch   24 batch   150
# Epoch   24 batch   200
# Epoch   24 batch   250
# Epoch   24 batch   300
# Epoch   24 batch   350
# Epoch   24 batch   400
# Epoch   24 batch   450
# [ 52.11759949] [54]
# Epoch   24 val.cost 0.000184 val.err 12.01% best
# Epoch   25 batch     0
# Epoch   25 batch    50
# Epoch   25 batch   100
# Epoch   25 batch   150
# Epoch   25 batch   200
# Epoch   25 batch   250
# Epoch   25 batch   300
# Epoch   25 batch   350
# Epoch   25 batch   400
# Epoch   25 batch   450
# [ 34.08228302] [35]
# Epoch   25 val.cost 0.000183 val.err 11.90% best
# Epoch   26 batch     0
# Epoch   26 batch    50
# Epoch   26 batch   100
# Epoch   26 batch   150
# Epoch   26 batch   200
# Epoch   26 batch   250
# Epoch   26 batch   300
# Epoch   26 batch   350
# Epoch   26 batch   400
# Epoch   26 batch   450
# [ 84.16477966] [82]
# Epoch   26 val.cost 0.000183 val.err 11.83% best
# Epoch   27 batch     0
# Epoch   27 batch    50
# Epoch   27 batch   100
# Epoch   27 batch   150
# Epoch   27 batch   200
# Epoch   27 batch   250
# Epoch   27 batch   300
# Epoch   27 batch   350
# Epoch   27 batch   400
# Epoch   27 batch   450
# [ 31.09055901] [33]
# Epoch   27 val.cost 0.000182 val.err 11.78% best
# Epoch   28 batch     0
# Epoch   28 batch    50
# Epoch   28 batch   100
# Epoch   28 batch   150
# Epoch   28 batch   200
# Epoch   28 batch   250
# Epoch   28 batch   300
# Epoch   28 batch   350
# Epoch   28 batch   400
# Epoch   28 batch   450
# [ 40.75715637] [42]
# Epoch   28 val.cost 0.000182 val.err 11.76% best
# Epoch   29 batch     0
# Epoch   29 batch    50
# Epoch   29 batch   100
# Epoch   29 batch   150
# Epoch   29 batch   200
# Epoch   29 batch   250
# Epoch   29 batch   300
# Epoch   29 batch   350
# Epoch   29 batch   400
# Epoch   29 batch   450
# [ 39.32572937] [54]
# Epoch   29 val.cost 0.000182 val.err 11.74% best
# Epoch   30 batch     0
# Epoch   30 batch    50
# Epoch   30 batch   100
# Epoch   30 batch   150
# Epoch   30 batch   200
# Epoch   30 batch   250
# Epoch   30 batch   300
# Epoch   30 batch   350
# Epoch   30 batch   400
# Epoch   30 batch   450
# [ 25.33499146] [8]
# Epoch   30 val.cost 0.000182 val.err 11.73% best
# Epoch   31 batch     0
# Epoch   31 batch    50
# Epoch   31 batch   100
# Epoch   31 batch   150
# Epoch   31 batch   200
# Epoch   31 batch   250
# Epoch   31 batch   300
# Epoch   31 batch   350
# Epoch   31 batch   400
# Epoch   31 batch   450
# [ 58.68903732] [60]
# Epoch   31 val.cost 0.000181 val.err 11.68% best
# Epoch   32 batch     0
# Epoch   32 batch    50
# Epoch   32 batch   100
# Epoch   32 batch   150
# Epoch   32 batch   200
# Epoch   32 batch   250
# Epoch   32 batch   300
# Epoch   32 batch   350
# Epoch   32 batch   400
# Epoch   32 batch   450
# [ 45.47849274] [45]
# Epoch   32 val.cost 0.000181 val.err 11.64% best
# Epoch   33 batch     0
# Epoch   33 batch    50
# Epoch   33 batch   100
# Epoch   33 batch   150
# Epoch   33 batch   200
# Epoch   33 batch   250
# Epoch   33 batch   300
# Epoch   33 batch   350
# Epoch   33 batch   400
# Epoch   33 batch   450
# [ 39.58896255] [41]
# Epoch   33 val.cost 0.000180 val.err 11.61% best
# Epoch   34 batch     0
# Epoch   34 batch    50
# Epoch   34 batch   100
# Epoch   34 batch   150
# Epoch   34 batch   200
# Epoch   34 batch   250
# Epoch   34 batch   300
# Epoch   34 batch   350
# Epoch   34 batch   400
# Epoch   34 batch   450
# [ 20.26967049] [20]
# Epoch   34 val.cost 0.000180 val.err 11.59% best
# Epoch   35 batch     0
# Epoch   35 batch    50
# Epoch   35 batch   100
# Epoch   35 batch   150
# Epoch   35 batch   200
# Epoch   35 batch   250
# Epoch   35 batch   300
# Epoch   35 batch   350
# Epoch   35 batch   400
# Epoch   35 batch   450
# [ 24.59853745] [0]
# Epoch   35 val.cost 0.000180 val.err 11.57% best
# Epoch   36 batch     0
# Epoch   36 batch    50
# Epoch   36 batch   100
# Epoch   36 batch   150
# Epoch   36 batch   200
# Epoch   36 batch   250
# Epoch   36 batch   300
# Epoch   36 batch   350
# Epoch   36 batch   400
# Epoch   36 batch   450
# [ 46.54803848] [46]
# Epoch   36 val.cost 0.000180 val.err 11.54% best
# Epoch   37 batch     0
# Epoch   37 batch    50
# Epoch   37 batch   100
# Epoch   37 batch   150
# Epoch   37 batch   200
# Epoch   37 batch   250
# Epoch   37 batch   300
# Epoch   37 batch   350
# Epoch   37 batch   400
# Epoch   37 batch   450
# [ 27.07232094] [55]
# Epoch   37 val.cost 0.000180 val.err 11.53% best
# Epoch   38 batch     0
# Epoch   38 batch    50
# Epoch   38 batch   100
# Epoch   38 batch   150
# Epoch   38 batch   200
# Epoch   38 batch   250
# Epoch   38 batch   300
# Epoch   38 batch   350
# Epoch   38 batch   400
# Epoch   38 batch   450
# [ 29.14222336] [42]
# Epoch   38 val.cost 0.000180 val.err 11.53% stopping   1
# Epoch   39 batch     0
# Epoch   39 batch    50
# Epoch   39 batch   100
# Epoch   39 batch   150
# Epoch   39 batch   200
# Epoch   39 batch   250
# Epoch   39 batch   300
# Epoch   39 batch   350
# Epoch   39 batch   400
# Epoch   39 batch   450
# [ 33.99475479] [33]
# Epoch   39 val.cost 0.000180 val.err 11.52% best
# Epoch   40 batch     0
# Epoch   40 batch    50
# Epoch   40 batch   100
# Epoch   40 batch   150
# Epoch   40 batch   200
# Epoch   40 batch   250
# Epoch   40 batch   300
# Epoch   40 batch   350
# Epoch   40 batch   400
# Epoch   40 batch   450
# [ 33.37073517] [34]
# Epoch   40 val.cost 0.000180 val.err 11.52% best
# Epoch   41 batch     0
# Epoch   41 batch    50
# Epoch   41 batch   100
# Epoch   41 batch   150
# Epoch   41 batch   200
# Epoch   41 batch   250
# Epoch   41 batch   300
# Epoch   41 batch   350
# Epoch   41 batch   400
# Epoch   41 batch   450
# [ 32.48709488] [17]
# Epoch   41 val.cost 0.000180 val.err 11.52% best
# Epoch   42 batch     0
# Epoch   42 batch    50
# Epoch   42 batch   100
# Epoch   42 batch   150
# Epoch   42 batch   200
# Epoch   42 batch   250
# Epoch   42 batch   300
# Epoch   42 batch   350
# Epoch   42 batch   400
# Epoch   42 batch   450
# [ 47.61169434] [49]
# Epoch   42 val.cost 0.000180 val.err 11.53% stopping   1
# Epoch   43 batch     0
# Epoch   43 batch    50
# Epoch   43 batch   100
# Epoch   43 batch   150
# Epoch   43 batch   200
# Epoch   43 batch   250
# Epoch   43 batch   300
# Epoch   43 batch   350
# Epoch   43 batch   400
# Epoch   43 batch   450
# [ 20.23940277] [21]
# Epoch   43 val.cost 0.000180 val.err 11.52% stopping   2
# Epoch   44 batch     0
# Epoch   44 batch    50
# Epoch   44 batch   100
# Epoch   44 batch   150
# Epoch   44 batch   200
# Epoch   44 batch   250
# Epoch   44 batch   300
# Epoch   44 batch   350
# Epoch   44 batch   400
# Epoch   44 batch   450
# [ 25.66045761] [31]
# Epoch   44 val.cost 0.000180 val.err 11.56% stopping   3
# Epoch   45 batch     0
# Epoch   45 batch    50
# Epoch   45 batch   100
# Epoch   45 batch   150
# Epoch   45 batch   200
# Epoch   45 batch   250
# Epoch   45 batch   300
# Epoch   45 batch   350
# Epoch   45 batch   400
# Epoch   45 batch   450
# [ 31.03972435] [10]
# Epoch   45 val.cost 0.000180 val.err 11.55% stopping   4
# Epoch   46 batch     0
# Epoch   46 batch    50
# Epoch   46 batch   100
# Epoch   46 batch   150
# Epoch   46 batch   200
# Epoch   46 batch   250
# Epoch   46 batch   300
# Epoch   46 batch   350
# Epoch   46 batch   400
# Epoch   46 batch   450
# [ 105.34700775] [105]
# Epoch   46 val.cost 0.000180 val.err 11.56% stopping   5
# Epoch   47 batch     0
# Epoch   47 batch    50
# Epoch   47 batch   100
# Epoch   47 batch   150
# Epoch   47 batch   200
# Epoch   47 batch   250
# Epoch   47 batch   300
# Epoch   47 batch   350
# Epoch   47 batch   400
# Epoch   47 batch   450
# [ 36.02528] [60]
# Epoch   47 val.cost 0.000180 val.err 11.65% stopping   6
# Epoch   48 batch     0
# Epoch   48 batch    50
# Epoch   48 batch   100
# Epoch   48 batch   150
# Epoch   48 batch   200
# Epoch   48 batch   250
# Epoch   48 batch   300
# Epoch   48 batch   350
# Epoch   48 batch   400
# Epoch   48 batch   450
# [ 50.16959381] [51]
# Epoch   48 val.cost 0.000181 val.err 11.67% stopping   7
# Epoch   49 batch     0
# Epoch   49 batch    50
# Epoch   49 batch   100
# Epoch   49 batch   150
# Epoch   49 batch   200
# Epoch   49 batch   250
# Epoch   49 batch   300
# Epoch   49 batch   350
# Epoch   49 batch   400
# Epoch   49 batch   450
# [ 28.6525116] [28]
# Epoch   49 val.cost 0.000181 val.err 11.85% stopping   8
# Epoch   50 batch     0
# Epoch   50 batch    50
# Epoch   50 batch   100
# Epoch   50 batch   150
# Epoch   50 batch   200
# Epoch   50 batch   250
# Epoch   50 batch   300
# Epoch   50 batch   350
# Epoch   50 batch   400
# Epoch   50 batch   450
# [ 15.28202438] [16]
# Epoch   50 val.cost 0.000181 val.err 11.89% stopping   9
# Epoch   51 batch     0
# Epoch   51 batch    50
# Epoch   51 batch   100
# Epoch   51 batch   150
# Epoch   51 batch   200
# Epoch   51 batch   250
# Epoch   51 batch   300
# Epoch   51 batch   350
# Epoch   51 batch   400
# Epoch   51 batch   450
# [ 64.43644714] [64]
# Epoch   51 val.cost 0.000181 val.err 11.90% stopping  10
# Early stopping triggered: Step:      23859, val.err 11.90%
# best model saved to: ./best_model/model_20180610_224109
# Total time: 1980.039399
# INFO:tensorflow:Restoring parameters from ./best_model/model_20180610_224109
# Test Err: 13.60%
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b'./final_model_3/saved_model.pb'
