# %%
# no lat, lon
import pandas as pd
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from datetime import datetime
from tensorflow.contrib.layers import fully_connected, batch_norm
import math
import numpy as np
import random

# %%
df = pd.read_csv('./DL_final_project/DL_Taiwan_data/sinica/201701_Taiwan.csv')
#把201701_Taiwan.csv的header的' lat',' lon'改成'lat','lon' (多了空格)
train_for_taiwan = False # filter out non-Taiwan
#len(df)

# %%
#df

# %%
#df.shape

# %%
#df.columns

# %%
#df.describe()

# %%
#df[['lat', 'lon']]
#df[:10]

# %%
#need_rows = 100000
## pd.options.display.max_rows=1000
#dfs = df.head(need_rows)
#df.head(need_rows)

# %%
#ax1 = dfs.plot.scatter(x='lon', y='lat', s=5)
#plt.show(ax1)

# %%
#df2 = df[['Date','Time']].head(10)
#df2 = df2.assign(Timestamp = pd.to_datetime(df2['Date']+' '+df2['Time']))
#df2 = df2.assign(Hour = df2['Timestamp'].dt.hour)
#df2

# %%
if train_for_taiwan:
    df = df[(df['lat']>= 22 )& (df['lat'] <= 25)&(df['lon']>=120)&(df['lon']<=122)]
df = df.assign(Timestamp = pd.to_datetime(df['Date']+' '+df['Time']))
df = df.assign(Hour = df['Timestamp'].dt.hour)
#df

# %%
df_X = df[['Hour','PM10','PM1','Temperature','Humidity']]
#df_X

# %%
dfa_X = df_X.values
#dfa_X

# %%
df_Y = df[['PM2.5']]
dfa_Y = df_Y.values
#dfa_Y

# %%
root_logdir = "tf_logs"
batch_log_step = 50
early_stopping_epochs = 10

# %%
def dnn(X_1, y_1, X_2, y_2, X_3, y_3, X_w):
    tf.reset_default_graph()
    
    # logs
    start_time = datetime.now()
    now = start_time.strftime("%Y%m%d_%H%M%S")
    logdir = "./{}/run-{}".format(root_logdir, now)
    
    # dnn graph defs
    n_input = 5
    n_epochs = 100
    n_hidden = [100,100,10]
    act_fn = tf.nn.sigmoid
    learning_rate = 0.001
    batch_normalization = False
    batch_size = 10000
    #batch_size = 1000 #小範圍測試用
    mult_bias = 1000

    # I/O
    with tf.name_scope("Input"):
        X = tf.placeholder(tf.float32, [None, n_input], name="X")
        is_training = tf.placeholder(tf.bool, shape=(), name="is_training")
    with tf.name_scope("Output"):
        y = tf.placeholder(tf.float32, [None, 1], name="y")
        y_biased = y/mult_bias
    
    # batch norm 
    he_init = tf.contrib.layers.variance_scaling_initializer()
    with tf.name_scope("BatchNormArgs"):
        bn_params = {
            'is_training': is_training,
            'decay': 0.99,
            'updates_collections': None,
            'scale': True
        }
    
    # DNN
    with tf.name_scope("DNN"):
        with tf.contrib.framework.arg_scope(
                [fully_connected],
                weights_initializer = he_init,
                normalizer_fn = batch_norm if batch_normalization else None,
                normalizer_params = bn_params if batch_normalization else None
                ):
            h1=fully_connected(X ,n_hidden[0],activation_fn=act_fn,scope="h1")
            h2=fully_connected(h1,n_hidden[1],activation_fn=act_fn,scope="h2")
            h3=fully_connected(h2,n_hidden[2],activation_fn=act_fn,scope="h3")
            logits=fully_connected(h3, 1, activation_fn=act_fn,scope="out")
    
    with tf.name_scope("Cost"):
        #cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y), name="cost")
        cost = tf.losses.mean_squared_error(logits, y_biased)
    with tf.name_scope("AdamOptimizer"):
        optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate)
        minimizer = optimizer.minimize(cost)
    
    init = tf.global_variables_initializer()
    with tf.name_scope("ModelSaver"):
        saver = tf.train.Saver()
    
    with tf.name_scope("Predict"):
        predict = logits * mult_bias
        
    with tf.name_scope("Error"):
        ave_of_batch_y = tf.reduce_mean(y_biased)
        error = tf.abs(logits - y_biased)/ave_of_batch_y
        relative_err = tf.reduce_mean(error)
    
    with tf.name_scope("Summaries-Train"):
        cost_summary = tf.summary.scalar('cost_function',cost)
        error_summary = tf.summary.scalar('relative_err',relative_err)
    with tf.name_scope("Summaries-Validation"):
        v_cost_summary = tf.summary.scalar('v_cost_function',cost)
        v_error_summary = tf.summary.scalar('v_relative_err',relative_err)
    file_writer = tf.summary.FileWriter(logdir, tf.get_default_graph())
    
    with tf.Session() as sess:
        sess.run(init)
        
        total_batch = len(X_1)//batch_size
        #total_batch = validation_idx_start//batch_size
        print("Total batch:",total_batch)
        #X_va, y_va = dfa_X[validation_idx_start:test_idx_start], dfa_Y[validation_idx_start:test_idx_start]
        X_va = X_2
        y_va = y_2
        X_test = X_3
        y_test = y_3
        
        best_va_err_triggered = False
        best_va_err = 0
        early_stopping_triggered = False
        stopping_epoch = 0
        step = 0
        save_path = ""
        best_save_path = ""
        
        perm = np.arange(len(X_1))
        np.random.shuffle(perm)
        X_t = X_1[perm]
        y_t = y_1[perm]
        
        for epoch in range(n_epochs):
            for batch in range(total_batch):
                X_ba = X_t[batch*batch_size: (batch+1)*batch_size]
                y_ba = y_t[batch*batch_size: (batch+1)*batch_size]
                _, c = sess.run([minimizer, cost], feed_dict = {is_training: True, X:X_ba, y:y_ba})
                
                if batch % batch_log_step == 0:
                    print("Epoch %4d batch %5d"%(epoch,batch))
                    cost_summary_str = cost_summary.eval(feed_dict={is_training:False, X:X_ba, y:y_ba})
                    step = epoch * total_batch + batch
                    file_writer.add_summary(cost_summary_str, step)
                    error_summary_str = error_summary.eval(feed_dict={is_training:False, X:X_ba, y:y_ba})
                    file_writer.add_summary(error_summary_str, step)
            
            save_path = saver.save(sess, "./checkpoint/model_"+now+".ckpt")
            va_err, va_cost = sess.run([relative_err, cost], feed_dict={is_training:False, X:X_va, y:y_va})
            va_l = sess.run(predict, feed_dict={is_training:False, X:X_va, y:y_va})
            rnd_result_idx = random.randint(0, len(X_va)-1)
            
            print(va_l[rnd_result_idx], y_va[rnd_result_idx]) # print 1st prediction result
            v_error_summary_str = v_error_summary.eval(feed_dict={is_training:False, X:X_va, y:y_va})
            file_writer.add_summary(v_error_summary_str, step)
            v_cost_summary_str = v_cost_summary.eval(feed_dict={is_training:False, X:X_va, y:y_va})
            file_writer.add_summary(v_cost_summary_str, step)
            print("Epoch %4d val.cost %3.6f val.err %3.2f%%"%(epoch,va_cost,va_err*100),end=" ")
            
            if best_va_err_triggered:
                if va_err < best_va_err:
                    print("best")
                    stopping_epoch = 0
                    best_va_err = va_err
                    
                    best_save_path = saver.save(sess, "./best_model/model_"+now)
                else:
                    stopping_epoch += 1
                    print("stopping %3d"%stopping_epoch)
                if stopping_epoch >= early_stopping_epochs:
                    early_stopping_triggered = True
                    print("Early stopping triggered: Step: %10d, val.err %3.2f%%"%(step, va_err*100))
            else:
                best_va_err = va_err
                best_va_err_triggered = True
                print("best")
                best_save_path = saver.save(sess, "./best_model/model_"+now)
            
            if early_stopping_triggered:
                break
        
        finish_time = datetime.now()
        print("best model saved to:", best_save_path)
        file_writer.close()
        elapse_time = finish_time - start_time
        total_seconds = elapse_time.total_seconds()
        print("Total time:", total_seconds)
        
        #X_test = dfa_X[test_idx_start:idx_end]
        #y_test = dfa_Y[test_idx_start:idx_end]
        saver.restore(sess, "./best_model/model_"+now)
        best_err = relative_err.eval({is_training: False, X: X_test, y: y_test})
        print("Test Err: %3.2f%%"%(best_err*100))
        
        
        print("Predicting...")
        predict_values = sess.run(predict, feed_dict={is_training: False, X: X_w})
        print("Predict End")
        return predict_values

# %%
# df2: validation
# df3: test
df2 = pd.read_csv('./DL_final_project/DL_Taiwan_data/sinica/201702_Taiwan.csv')
df3 = pd.read_csv('./DL_final_project/DL_Taiwan_data/sinica/201702_Taiwan.csv')
test_idx_start = math.floor(len(df2)*0.5)
df2 = df2[:test_idx_start]
df3 = df3[test_idx_start:]
if train_for_taiwan:
    df2 = df2[(df2['lat']>= 22 )& (df2['lat'] <= 25)&(df2['lon']>=120)&(df2['lon']<=122)]
df2 = df2.assign(Timestamp = pd.to_datetime(df2['Date']+' '+df2['Time']))
df3 = df3.assign(Timestamp = pd.to_datetime(df3['Date']+' '+df3['Time']))
df2 = df2.assign(Hour = df2['Timestamp'].dt.hour)
df3 = df3.assign(Hour = df3['Timestamp'].dt.hour)
df2_X = df2[['Hour','PM10','PM1','Temperature','Humidity']]
df2_y = df2[['PM2.5']]
df3_X = df3[['Hour','PM10','PM1','Temperature','Humidity']]
df3_y = df3[['PM2.5']]
df2a_X = df2_X.values
df2a_y = df2_y.values
df3a_X = df3_X.values
df3a_y = df3_y.values

# %%
#dnn(dfa_X, dfa_Y, df2a_vX, df2a_vy, df3a_tX, df3a_ty)

# %%
#df[(df['lat']>= 22 )& (df['lat'] <= 25)&(df['lon']>=120)&(df['lon']<=122)&(df['PM2.5']>700)]

# %%
# write predict to file
dw = pd.read_csv('./DL_final_project/DL_Taiwan_data/sinica/201703_Taiwan.csv')
dfw = dw.assign(Timestamp = pd.to_datetime(dw['Date']+' '+dw['Time']))
dfw = dfw.assign(Hour = dfw['Timestamp'].dt.hour)
dfw_X = dfw[['Hour','PM10','PM1','Temperature','Humidity']]
dfwa_X = dfw_X.values
#dw

# %%
predicted_values = dnn(dfa_X, dfa_Y, df2a_X, df2a_y, df3a_X, df3a_y, dfwa_X)
# Out:
# Total batch: 493
# Epoch    0 batch     0
# Epoch    0 batch    50
# Epoch    0 batch   100
# Epoch    0 batch   150
# Epoch    0 batch   200
# Epoch    0 batch   250
# Epoch    0 batch   300
# Epoch    0 batch   350
# Epoch    0 batch   400
# Epoch    0 batch   450
# [ 253.93536377] [42]
# Epoch    0 val.cost 0.046782 val.err 553.19% best
# Epoch    1 batch     0
# Epoch    1 batch    50
# Epoch    1 batch   100
# Epoch    1 batch   150
# Epoch    1 batch   200
# Epoch    1 batch   250
# Epoch    1 batch   300
# Epoch    1 batch   350
# Epoch    1 batch   400
# Epoch    1 batch   450
# [ 146.38746643] [44]
# Epoch    1 val.cost 0.012087 val.err 276.83% best
# Epoch    2 batch     0
# Epoch    2 batch    50
# Epoch    2 batch   100
# Epoch    2 batch   150
# Epoch    2 batch   200
# Epoch    2 batch   250
# Epoch    2 batch   300
# Epoch    2 batch   350
# Epoch    2 batch   400
# Epoch    2 batch   450
# [ 86.2672348] [44]
# Epoch    2 val.cost 0.002776 val.err 123.40% best
# Epoch    3 batch     0
# Epoch    3 batch    50
# Epoch    3 batch   100
# Epoch    3 batch   150
# Epoch    3 batch   200
# Epoch    3 batch   250
# Epoch    3 batch   300
# Epoch    3 batch   350
# Epoch    3 batch   400
# Epoch    3 batch   450
# [ 66.75673676] [57]
# Epoch    3 val.cost 0.001310 val.err 76.89% best
# Epoch    4 batch     0
# Epoch    4 batch    50
# Epoch    4 batch   100
# Epoch    4 batch   150
# Epoch    4 batch   200
# Epoch    4 batch   250
# Epoch    4 batch   300
# Epoch    4 batch   350
# Epoch    4 batch   400
# Epoch    4 batch   450
# [ 56.35698318] [35]
# Epoch    4 val.cost 0.000839 val.err 55.93% best
# Epoch    5 batch     0
# Epoch    5 batch    50
# Epoch    5 batch   100
# Epoch    5 batch   150
# Epoch    5 batch   200
# Epoch    5 batch   250
# Epoch    5 batch   300
# Epoch    5 batch   350
# Epoch    5 batch   400
# Epoch    5 batch   450
# [ 49.93717194] [34]
# Epoch    5 val.cost 0.000656 val.err 46.62% best
# Epoch    6 batch     0
# Epoch    6 batch    50
# Epoch    6 batch   100
# Epoch    6 batch   150
# Epoch    6 batch   200
# Epoch    6 batch   250
# Epoch    6 batch   300
# Epoch    6 batch   350
# Epoch    6 batch   400
# Epoch    6 batch   450
# [ 45.74060822] [14]
# Epoch    6 val.cost 0.000581 val.err 42.72% best
# Epoch    7 batch     0
# Epoch    7 batch    50
# Epoch    7 batch   100
# Epoch    7 batch   150
# Epoch    7 batch   200
# Epoch    7 batch   250
# Epoch    7 batch   300
# Epoch    7 batch   350
# Epoch    7 batch   400
# Epoch    7 batch   450
# [ 42.96934128] [41]
# Epoch    7 val.cost 0.000551 val.err 41.20% best
# Epoch    8 batch     0
# Epoch    8 batch    50
# Epoch    8 batch   100
# Epoch    8 batch   150
# Epoch    8 batch   200
# Epoch    8 batch   250
# Epoch    8 batch   300
# Epoch    8 batch   350
# Epoch    8 batch   400
# Epoch    8 batch   450
# [ 41.20302582] [83]
# Epoch    8 val.cost 0.000540 val.err 40.70% best
# Epoch    9 batch     0
# Epoch    9 batch    50
# Epoch    9 batch   100
# Epoch    9 batch   150
# Epoch    9 batch   200
# Epoch    9 batch   250
# Epoch    9 batch   300
# Epoch    9 batch   350
# Epoch    9 batch   400
# Epoch    9 batch   450
# [ 40.1566658] [66]
# Epoch    9 val.cost 0.000536 val.err 40.58% best
# Epoch   10 batch     0
# Epoch   10 batch    50
# Epoch   10 batch   100
# Epoch   10 batch   150
# Epoch   10 batch   200
# Epoch   10 batch   250
# Epoch   10 batch   300
# Epoch   10 batch   350
# Epoch   10 batch   400
# Epoch   10 batch   450
# [ 39.61300659] [53]
# Epoch   10 val.cost 0.000535 val.err 40.56% best
# Epoch   11 batch     0
# Epoch   11 batch    50
# Epoch   11 batch   100
# Epoch   11 batch   150
# Epoch   11 batch   200
# Epoch   11 batch   250
# Epoch   11 batch   300
# Epoch   11 batch   350
# Epoch   11 batch   400
# Epoch   11 batch   450
# [ 39.38035583] [64]
# Epoch   11 val.cost 0.000535 val.err 40.56% best
# Epoch   12 batch     0
# Epoch   12 batch    50
# Epoch   12 batch   100
# Epoch   12 batch   150
# Epoch   12 batch   200
# Epoch   12 batch   250
# Epoch   12 batch   300
# Epoch   12 batch   350
# Epoch   12 batch   400
# Epoch   12 batch   450
# [ 39.30363083] [17]
# Epoch   12 val.cost 0.000535 val.err 40.55% best
# Epoch   13 batch     0
# Epoch   13 batch    50
# Epoch   13 batch   100
# Epoch   13 batch   150
# Epoch   13 batch   200
# Epoch   13 batch   250
# Epoch   13 batch   300
# Epoch   13 batch   350
# Epoch   13 batch   400
# Epoch   13 batch   450
# [ 39.28598022] [55]
# Epoch   13 val.cost 0.000535 val.err 40.56% stopping   1
# Epoch   14 batch     0
# Epoch   14 batch    50
# Epoch   14 batch   100
# Epoch   14 batch   150
# Epoch   14 batch   200
# Epoch   14 batch   250
# Epoch   14 batch   300
# Epoch   14 batch   350
# Epoch   14 batch   400
# Epoch   14 batch   450
# [ 39.28238297] [37]
# Epoch   14 val.cost 0.000535 val.err 40.56% stopping   2
# Epoch   15 batch     0
# Epoch   15 batch    50
# Epoch   15 batch   100
# Epoch   15 batch   150
# Epoch   15 batch   200
# Epoch   15 batch   250
# Epoch   15 batch   300
# Epoch   15 batch   350
# Epoch   15 batch   400
# Epoch   15 batch   450
# [ 39.28329086] [65]
# Epoch   15 val.cost 0.000535 val.err 40.56% stopping   3
# Epoch   16 batch     0
# Epoch   16 batch    50
# Epoch   16 batch   100
# Epoch   16 batch   150
# Epoch   16 batch   200
# Epoch   16 batch   250
# Epoch   16 batch   300
# Epoch   16 batch   350
# Epoch   16 batch   400
# Epoch   16 batch   450
# [ 39.28259659] [56]
# Epoch   16 val.cost 0.000535 val.err 40.56% stopping   4
# Epoch   17 batch     0
# Epoch   17 batch    50
# Epoch   17 batch   100
# Epoch   17 batch   150
# Epoch   17 batch   200
# Epoch   17 batch   250
# Epoch   17 batch   300
# Epoch   17 batch   350
# Epoch   17 batch   400
# Epoch   17 batch   450
# [ 39.2801857] [24]
# Epoch   17 val.cost 0.000535 val.err 40.56% stopping   5
# Epoch   18 batch     0
# Epoch   18 batch    50
# Epoch   18 batch   100
# Epoch   18 batch   150
# Epoch   18 batch   200
# Epoch   18 batch   250
# Epoch   18 batch   300
# Epoch   18 batch   350
# Epoch   18 batch   400
# Epoch   18 batch   450
# [ 39.28223801] [37]
# Epoch   18 val.cost 0.000535 val.err 40.56% stopping   6
# Epoch   19 batch     0
# Epoch   19 batch    50
# Epoch   19 batch   100
# Epoch   19 batch   150
# Epoch   19 batch   200
# Epoch   19 batch   250
# Epoch   19 batch   300
# Epoch   19 batch   350
# Epoch   19 batch   400
# Epoch   19 batch   450
# [ 39.28879547] [54]
# Epoch   19 val.cost 0.000535 val.err 40.56% stopping   7
# Epoch   20 batch     0
# Epoch   20 batch    50
# Epoch   20 batch   100
# Epoch   20 batch   150
# Epoch   20 batch   200
# Epoch   20 batch   250
# Epoch   20 batch   300
# Epoch   20 batch   350
# Epoch   20 batch   400
# Epoch   20 batch   450
# [ 39.29069519] [53]
# Epoch   20 val.cost 0.000535 val.err 40.55% best
# Epoch   21 batch     0
# Epoch   21 batch    50
# Epoch   21 batch   100
# Epoch   21 batch   150
# Epoch   21 batch   200
# Epoch   21 batch   250
# Epoch   21 batch   300
# Epoch   21 batch   350
# Epoch   21 batch   400
# Epoch   21 batch   450
# [ 29.88287163] [22]
# Epoch   21 val.cost 0.000299 val.err 24.40% best
# Epoch   22 batch     0
# Epoch   22 batch    50
# Epoch   22 batch   100
# Epoch   22 batch   150
# Epoch   22 batch   200
# Epoch   22 batch   250
# Epoch   22 batch   300
# Epoch   22 batch   350
# Epoch   22 batch   400
# Epoch   22 batch   450
# [ 24.9656105] [12]
# Epoch   22 val.cost 0.000280 val.err 22.07% best
# Epoch   23 batch     0
# Epoch   23 batch    50
# Epoch   23 batch   100
# Epoch   23 batch   150
# Epoch   23 batch   200
# Epoch   23 batch   250
# Epoch   23 batch   300
# Epoch   23 batch   350
# Epoch   23 batch   400
# Epoch   23 batch   450
# [ 24.67001152] [40]
# Epoch   23 val.cost 0.000269 val.err 20.77% best
# Epoch   24 batch     0
# Epoch   24 batch    50
# Epoch   24 batch   100
# Epoch   24 batch   150
# Epoch   24 batch   200
# Epoch   24 batch   250
# Epoch   24 batch   300
# Epoch   24 batch   350
# Epoch   24 batch   400
# Epoch   24 batch   450
# [ 38.78176498] [37]
# Epoch   24 val.cost 0.000224 val.err 18.24% best
# Epoch   25 batch     0
# Epoch   25 batch    50
# Epoch   25 batch   100
# Epoch   25 batch   150
# Epoch   25 batch   200
# Epoch   25 batch   250
# Epoch   25 batch   300
# Epoch   25 batch   350
# Epoch   25 batch   400
# Epoch   25 batch   450
# [ 24.03295898] [13]
# Epoch   25 val.cost 0.000217 val.err 17.11% best
# Epoch   26 batch     0
# Epoch   26 batch    50
# Epoch   26 batch   100
# Epoch   26 batch   150
# Epoch   26 batch   200
# Epoch   26 batch   250
# Epoch   26 batch   300
# Epoch   26 batch   350
# Epoch   26 batch   400
# Epoch   26 batch   450
# [ 43.78879929] [44]
# Epoch   26 val.cost 0.000213 val.err 16.74% best
# Epoch   27 batch     0
# Epoch   27 batch    50
# Epoch   27 batch   100
# Epoch   27 batch   150
# Epoch   27 batch   200
# Epoch   27 batch   250
# Epoch   27 batch   300
# Epoch   27 batch   350
# Epoch   27 batch   400
# Epoch   27 batch   450
# [ 28.39816093] [17]
# Epoch   27 val.cost 0.000210 val.err 16.57% best
# Epoch   28 batch     0
# Epoch   28 batch    50
# Epoch   28 batch   100
# Epoch   28 batch   150
# Epoch   28 batch   200
# Epoch   28 batch   250
# Epoch   28 batch   300
# Epoch   28 batch   350
# Epoch   28 batch   400
# Epoch   28 batch   450
# [ 96.28595734] [91]
# Epoch   28 val.cost 0.000209 val.err 16.44% best
# Epoch   29 batch     0
# Epoch   29 batch    50
# Epoch   29 batch   100
# Epoch   29 batch   150
# Epoch   29 batch   200
# Epoch   29 batch   250
# Epoch   29 batch   300
# Epoch   29 batch   350
# Epoch   29 batch   400
# Epoch   29 batch   450
# [ 60.54115677] [59]
# Epoch   29 val.cost 0.000207 val.err 16.17% best
# Epoch   30 batch     0
# Epoch   30 batch    50
# Epoch   30 batch   100
# Epoch   30 batch   150
# Epoch   30 batch   200
# Epoch   30 batch   250
# Epoch   30 batch   300
# Epoch   30 batch   350
# Epoch   30 batch   400
# Epoch   30 batch   450
# [ 25.35739136] [4]
# Epoch   30 val.cost 0.000189 val.err 14.64% best
# Epoch   31 batch     0
# Epoch   31 batch    50
# Epoch   31 batch   100
# Epoch   31 batch   150
# Epoch   31 batch   200
# Epoch   31 batch   250
# Epoch   31 batch   300
# Epoch   31 batch   350
# Epoch   31 batch   400
# Epoch   31 batch   450
# [ 58.2252655] [57]
# Epoch   31 val.cost 0.000180 val.err 13.14% best
# Epoch   32 batch     0
# Epoch   32 batch    50
# Epoch   32 batch   100
# Epoch   32 batch   150
# Epoch   32 batch   200
# Epoch   32 batch   250
# Epoch   32 batch   300
# Epoch   32 batch   350
# Epoch   32 batch   400
# Epoch   32 batch   450
# [ 16.79644775] [16]
# Epoch   32 val.cost 0.000177 val.err 12.72% best
# Epoch   33 batch     0
# Epoch   33 batch    50
# Epoch   33 batch   100
# Epoch   33 batch   150
# Epoch   33 batch   200
# Epoch   33 batch   250
# Epoch   33 batch   300
# Epoch   33 batch   350
# Epoch   33 batch   400
# Epoch   33 batch   450
# [ 28.60632896] [30]
# Epoch   33 val.cost 0.000177 val.err 12.57% best
# Epoch   34 batch     0
# Epoch   34 batch    50
# Epoch   34 batch   100
# Epoch   34 batch   150
# Epoch   34 batch   200
# Epoch   34 batch   250
# Epoch   34 batch   300
# Epoch   34 batch   350
# Epoch   34 batch   400
# Epoch   34 batch   450
# [ 30.34173965] [47]
# Epoch   34 val.cost 0.000177 val.err 12.43% best
# Epoch   35 batch     0
# Epoch   35 batch    50
# Epoch   35 batch   100
# Epoch   35 batch   150
# Epoch   35 batch   200
# Epoch   35 batch   250
# Epoch   35 batch   300
# Epoch   35 batch   350
# Epoch   35 batch   400
# Epoch   35 batch   450
# [ 102.13483429] [101]
# Epoch   35 val.cost 0.000176 val.err 12.37% best
# Epoch   36 batch     0
# Epoch   36 batch    50
# Epoch   36 batch   100
# Epoch   36 batch   150
# Epoch   36 batch   200
# Epoch   36 batch   250
# Epoch   36 batch   300
# Epoch   36 batch   350
# Epoch   36 batch   400
# Epoch   36 batch   450
# [ 26.52793884] [27]
# Epoch   36 val.cost 0.000176 val.err 12.20% best
# Epoch   37 batch     0
# Epoch   37 batch    50
# Epoch   37 batch   100
# Epoch   37 batch   150
# Epoch   37 batch   200
# Epoch   37 batch   250
# Epoch   37 batch   300
# Epoch   37 batch   350
# Epoch   37 batch   400
# Epoch   37 batch   450
# [ 30.80176926] [56]
# Epoch   37 val.cost 0.000176 val.err 12.15% best
# Epoch   38 batch     0
# Epoch   38 batch    50
# Epoch   38 batch   100
# Epoch   38 batch   150
# Epoch   38 batch   200
# Epoch   38 batch   250
# Epoch   38 batch   300
# Epoch   38 batch   350
# Epoch   38 batch   400
# Epoch   38 batch   450
# [ 32.80967712] [38]
# Epoch   38 val.cost 0.000176 val.err 12.09% best
# Epoch   39 batch     0
# Epoch   39 batch    50
# Epoch   39 batch   100
# Epoch   39 batch   150
# Epoch   39 batch   200
# Epoch   39 batch   250
# Epoch   39 batch   300
# Epoch   39 batch   350
# Epoch   39 batch   400
# Epoch   39 batch   450
# [ 43.26113129] [45]
# Epoch   39 val.cost 0.000175 val.err 12.03% best
# Epoch   40 batch     0
# Epoch   40 batch    50
# Epoch   40 batch   100
# Epoch   40 batch   150
# Epoch   40 batch   200
# Epoch   40 batch   250
# Epoch   40 batch   300
# Epoch   40 batch   350
# Epoch   40 batch   400
# Epoch   40 batch   450
# [ 44.01108551] [44]
# Epoch   40 val.cost 0.000175 val.err 11.98% best
# Epoch   41 batch     0
# Epoch   41 batch    50
# Epoch   41 batch   100
# Epoch   41 batch   150
# Epoch   41 batch   200
# Epoch   41 batch   250
# Epoch   41 batch   300
# Epoch   41 batch   350
# Epoch   41 batch   400
# Epoch   41 batch   450
# [ 75.46996307] [76]
# Epoch   41 val.cost 0.000175 val.err 11.94% best
# Epoch   42 batch     0
# Epoch   42 batch    50
# Epoch   42 batch   100
# Epoch   42 batch   150
# Epoch   42 batch   200
# Epoch   42 batch   250
# Epoch   42 batch   300
# Epoch   42 batch   350
# Epoch   42 batch   400
# Epoch   42 batch   450
# [ 25.94041824] [6]
# Epoch   42 val.cost 0.000175 val.err 11.91% best
# Epoch   43 batch     0
# Epoch   43 batch    50
# Epoch   43 batch   100
# Epoch   43 batch   150
# Epoch   43 batch   200
# Epoch   43 batch   250
# Epoch   43 batch   300
# Epoch   43 batch   350
# Epoch   43 batch   400
# Epoch   43 batch   450
# [ 9.07905579] [8]
# Epoch   43 val.cost 0.000175 val.err 11.89% best
# Epoch   44 batch     0
# Epoch   44 batch    50
# Epoch   44 batch   100
# Epoch   44 batch   150
# Epoch   44 batch   200
# Epoch   44 batch   250
# Epoch   44 batch   300
# Epoch   44 batch   350
# Epoch   44 batch   400
# Epoch   44 batch   450
# [ 22.94474411] [24]
# Epoch   44 val.cost 0.000174 val.err 11.87% best
# Epoch   45 batch     0
# Epoch   45 batch    50
# Epoch   45 batch   100
# Epoch   45 batch   150
# Epoch   45 batch   200
# Epoch   45 batch   250
# Epoch   45 batch   300
# Epoch   45 batch   350
# Epoch   45 batch   400
# Epoch   45 batch   450
# [ 41.37965012] [43]
# Epoch   45 val.cost 0.000174 val.err 11.84% best
# Epoch   46 batch     0
# Epoch   46 batch    50
# Epoch   46 batch   100
# Epoch   46 batch   150
# Epoch   46 batch   200
# Epoch   46 batch   250
# Epoch   46 batch   300
# Epoch   46 batch   350
# Epoch   46 batch   400
# Epoch   46 batch   450
# [ 10.31719685] [11]
# Epoch   46 val.cost 0.000174 val.err 11.83% best
# Epoch   47 batch     0
# Epoch   47 batch    50
# Epoch   47 batch   100
# Epoch   47 batch   150
# Epoch   47 batch   200
# Epoch   47 batch   250
# Epoch   47 batch   300
# Epoch   47 batch   350
# Epoch   47 batch   400
# Epoch   47 batch   450
# [ 14.5685873] [14]
# Epoch   47 val.cost 0.000174 val.err 11.83% stopping   1
# Epoch   48 batch     0
# Epoch   48 batch    50
# Epoch   48 batch   100
# Epoch   48 batch   150
# Epoch   48 batch   200
# Epoch   48 batch   250
# Epoch   48 batch   300
# Epoch   48 batch   350
# Epoch   48 batch   400
# Epoch   48 batch   450
# [ 86.74075317] [99]
# Epoch   48 val.cost 0.000174 val.err 11.80% best
# Epoch   49 batch     0
# Epoch   49 batch    50
# Epoch   49 batch   100
# Epoch   49 batch   150
# Epoch   49 batch   200
# Epoch   49 batch   250
# Epoch   49 batch   300
# Epoch   49 batch   350
# Epoch   49 batch   400
# Epoch   49 batch   450
# [ 46.48773956] [46]
# Epoch   49 val.cost 0.000174 val.err 11.82% stopping   1
# Epoch   50 batch     0
# Epoch   50 batch    50
# Epoch   50 batch   100
# Epoch   50 batch   150
# Epoch   50 batch   200
# Epoch   50 batch   250
# Epoch   50 batch   300
# Epoch   50 batch   350
# Epoch   50 batch   400
# Epoch   50 batch   450
# [ 41.997509] [42]
# Epoch   50 val.cost 0.000174 val.err 11.74% best
# Epoch   51 batch     0
# Epoch   51 batch    50
# Epoch   51 batch   100
# Epoch   51 batch   150
# Epoch   51 batch   200
# Epoch   51 batch   250
# Epoch   51 batch   300
# Epoch   51 batch   350
# Epoch   51 batch   400
# Epoch   51 batch   450
# [ 22.84209061] [23]
# Epoch   51 val.cost 0.000174 val.err 11.76% stopping   1
# Epoch   52 batch     0
# Epoch   52 batch    50
# Epoch   52 batch   100
# Epoch   52 batch   150
# Epoch   52 batch   200
# Epoch   52 batch   250
# Epoch   52 batch   300
# Epoch   52 batch   350
# Epoch   52 batch   400
# Epoch   52 batch   450
# [ 18.67350769] [19]
# Epoch   52 val.cost 0.000174 val.err 11.73% best
# Epoch   53 batch     0
# Epoch   53 batch    50
# Epoch   53 batch   100
# Epoch   53 batch   150
# Epoch   53 batch   200
# Epoch   53 batch   250
# Epoch   53 batch   300
# Epoch   53 batch   350
# Epoch   53 batch   400
# Epoch   53 batch   450
# [ 37.5249176] [38]
# Epoch   53 val.cost 0.000174 val.err 11.71% best
# Epoch   54 batch     0
# Epoch   54 batch    50
# Epoch   54 batch   100
# Epoch   54 batch   150
# Epoch   54 batch   200
# Epoch   54 batch   250
# Epoch   54 batch   300
# Epoch   54 batch   350
# Epoch   54 batch   400
# Epoch   54 batch   450
# [ 18.02877426] [17]
# Epoch   54 val.cost 0.000173 val.err 11.87% stopping   1
# Epoch   55 batch     0
# Epoch   55 batch    50
# Epoch   55 batch   100
# Epoch   55 batch   150
# Epoch   55 batch   200
# Epoch   55 batch   250
# Epoch   55 batch   300
# Epoch   55 batch   350
# Epoch   55 batch   400
# Epoch   55 batch   450
# [ 67.14875793] [66]
# Epoch   55 val.cost 0.000173 val.err 11.77% stopping   2
# Epoch   56 batch     0
# Epoch   56 batch    50
# Epoch   56 batch   100
# Epoch   56 batch   150
# Epoch   56 batch   200
# Epoch   56 batch   250
# Epoch   56 batch   300
# Epoch   56 batch   350
# Epoch   56 batch   400
# Epoch   56 batch   450
# [ 76.05191803] [79]
# Epoch   56 val.cost 0.000173 val.err 11.69% best
# Epoch   57 batch     0
# Epoch   57 batch    50
# Epoch   57 batch   100
# Epoch   57 batch   150
# Epoch   57 batch   200
# Epoch   57 batch   250
# Epoch   57 batch   300
# Epoch   57 batch   350
# Epoch   57 batch   400
# Epoch   57 batch   450
# [ 61.49274445] [60]
# Epoch   57 val.cost 0.000173 val.err 11.77% stopping   1
# Epoch   58 batch     0
# Epoch   58 batch    50
# Epoch   58 batch   100
# Epoch   58 batch   150
# Epoch   58 batch   200
# Epoch   58 batch   250
# Epoch   58 batch   300
# Epoch   58 batch   350
# Epoch   58 batch   400
# Epoch   58 batch   450
# [ 29.4465065] [0]
# Epoch   58 val.cost 0.000174 val.err 11.67% best
# Epoch   59 batch     0
# Epoch   59 batch    50
# Epoch   59 batch   100
# Epoch   59 batch   150
# Epoch   59 batch   200
# Epoch   59 batch   250
# Epoch   59 batch   300
# Epoch   59 batch   350
# Epoch   59 batch   400
# Epoch   59 batch   450
# [ 57.47715759] [57]
# Epoch   59 val.cost 0.000174 val.err 11.68% stopping   1
# Epoch   60 batch     0
# Epoch   60 batch    50
# Epoch   60 batch   100
# Epoch   60 batch   150
# Epoch   60 batch   200
# Epoch   60 batch   250
# Epoch   60 batch   300
# Epoch   60 batch   350
# Epoch   60 batch   400
# Epoch   60 batch   450
# [ 53.94814682] [56]
# Epoch   60 val.cost 0.000174 val.err 11.71% stopping   2
# Epoch   61 batch     0
# Epoch   61 batch    50
# Epoch   61 batch   100
# Epoch   61 batch   150
# Epoch   61 batch   200
# Epoch   61 batch   250
# Epoch   61 batch   300
# Epoch   61 batch   350
# Epoch   61 batch   400
# Epoch   61 batch   450
# [ 22.38699341] [1]
# Epoch   61 val.cost 0.000173 val.err 11.66% best
# Epoch   62 batch     0
# Epoch   62 batch    50
# Epoch   62 batch   100
# Epoch   62 batch   150
# Epoch   62 batch   200
# Epoch   62 batch   250
# Epoch   62 batch   300
# Epoch   62 batch   350
# Epoch   62 batch   400
# Epoch   62 batch   450
# [ 32.39666748] [30]
# Epoch   62 val.cost 0.000173 val.err 11.64% best
# Epoch   63 batch     0
# Epoch   63 batch    50
# Epoch   63 batch   100
# Epoch   63 batch   150
# Epoch   63 batch   200
# Epoch   63 batch   250
# Epoch   63 batch   300
# Epoch   63 batch   350
# Epoch   63 batch   400
# Epoch   63 batch   450
# [ 30.27623558] [41]
# Epoch   63 val.cost 0.000172 val.err 11.64% stopping   1
# Epoch   64 batch     0
# Epoch   64 batch    50
# Epoch   64 batch   100
# Epoch   64 batch   150
# Epoch   64 batch   200
# Epoch   64 batch   250
# Epoch   64 batch   300
# Epoch   64 batch   350
# Epoch   64 batch   400
# Epoch   64 batch   450
# [ 84.4543457] [85]
# Epoch   64 val.cost 0.000173 val.err 11.61% best
# Epoch   65 batch     0
# Epoch   65 batch    50
# Epoch   65 batch   100
# Epoch   65 batch   150
# Epoch   65 batch   200
# Epoch   65 batch   250
# Epoch   65 batch   300
# Epoch   65 batch   350
# Epoch   65 batch   400
# Epoch   65 batch   450
# [ 30.77644539] [29]
# Epoch   65 val.cost 0.000173 val.err 11.60% best
# Epoch   66 batch     0
# Epoch   66 batch    50
# Epoch   66 batch   100
# Epoch   66 batch   150
# Epoch   66 batch   200
# Epoch   66 batch   250
# Epoch   66 batch   300
# Epoch   66 batch   350
# Epoch   66 batch   400
# Epoch   66 batch   450
# [ 61.88378906] [63]
# Epoch   66 val.cost 0.000172 val.err 11.60% stopping   1
# Epoch   67 batch     0
# Epoch   67 batch    50
# Epoch   67 batch   100
# Epoch   67 batch   150
# Epoch   67 batch   200
# Epoch   67 batch   250
# Epoch   67 batch   300
# Epoch   67 batch   350
# Epoch   67 batch   400
# Epoch   67 batch   450
# [ 26.08570099] [21]
# Epoch   67 val.cost 0.000173 val.err 11.63% stopping   2
# Epoch   68 batch     0
# Epoch   68 batch    50
# Epoch   68 batch   100
# Epoch   68 batch   150
# Epoch   68 batch   200
# Epoch   68 batch   250
# Epoch   68 batch   300
# Epoch   68 batch   350
# Epoch   68 batch   400
# Epoch   68 batch   450
# [ 59.25852585] [59]
# Epoch   68 val.cost 0.000172 val.err 11.59% best
# Epoch   69 batch     0
# Epoch   69 batch    50
# Epoch   69 batch   100
# Epoch   69 batch   150
# Epoch   69 batch   200
# Epoch   69 batch   250
# Epoch   69 batch   300
# Epoch   69 batch   350
# Epoch   69 batch   400
# Epoch   69 batch   450
# [ 37.23510361] [36]
# Epoch   69 val.cost 0.000172 val.err 11.56% best
# Epoch   70 batch     0
# Epoch   70 batch    50
# Epoch   70 batch   100
# Epoch   70 batch   150
# Epoch   70 batch   200
# Epoch   70 batch   250
# Epoch   70 batch   300
# Epoch   70 batch   350
# Epoch   70 batch   400
# Epoch   70 batch   450
# [ 28.36688805] [30]
# Epoch   70 val.cost 0.000173 val.err 11.71% stopping   1
# Epoch   71 batch     0
# Epoch   71 batch    50
# Epoch   71 batch   100
# Epoch   71 batch   150
# Epoch   71 batch   200
# Epoch   71 batch   250
# Epoch   71 batch   300
# Epoch   71 batch   350
# Epoch   71 batch   400
# Epoch   71 batch   450
# [ 4.39699316] [1]
# Epoch   71 val.cost 0.000173 val.err 11.55% best
# Epoch   72 batch     0
# Epoch   72 batch    50
# Epoch   72 batch   100
# Epoch   72 batch   150
# Epoch   72 batch   200
# Epoch   72 batch   250
# Epoch   72 batch   300
# Epoch   72 batch   350
# Epoch   72 batch   400
# Epoch   72 batch   450
# [ 26.64134216] [53]
# Epoch   72 val.cost 0.000172 val.err 11.55% best
# Epoch   73 batch     0
# Epoch   73 batch    50
# Epoch   73 batch   100
# Epoch   73 batch   150
# Epoch   73 batch   200
# Epoch   73 batch   250
# Epoch   73 batch   300
# Epoch   73 batch   350
# Epoch   73 batch   400
# Epoch   73 batch   450
# [ 39.97831726] [40]
# Epoch   73 val.cost 0.000173 val.err 11.62% stopping   1
# Epoch   74 batch     0
# Epoch   74 batch    50
# Epoch   74 batch   100
# Epoch   74 batch   150
# Epoch   74 batch   200
# Epoch   74 batch   250
# Epoch   74 batch   300
# Epoch   74 batch   350
# Epoch   74 batch   400
# Epoch   74 batch   450
# [ 42.3554306] [43]
# Epoch   74 val.cost 0.000172 val.err 11.65% stopping   2
# Epoch   75 batch     0
# Epoch   75 batch    50
# Epoch   75 batch   100
# Epoch   75 batch   150
# Epoch   75 batch   200
# Epoch   75 batch   250
# Epoch   75 batch   300
# Epoch   75 batch   350
# Epoch   75 batch   400
# Epoch   75 batch   450
# [ 40.95874023] [43]
# Epoch   75 val.cost 0.000172 val.err 11.75% stopping   3
# Epoch   76 batch     0
# Epoch   76 batch    50
# Epoch   76 batch   100
# Epoch   76 batch   150
# Epoch   76 batch   200
# Epoch   76 batch   250
# Epoch   76 batch   300
# Epoch   76 batch   350
# Epoch   76 batch   400
# Epoch   76 batch   450
# [ 46.07461929] [47]
# Epoch   76 val.cost 0.000172 val.err 11.63% stopping   4
# Epoch   77 batch     0
# Epoch   77 batch    50
# Epoch   77 batch   100
# Epoch   77 batch   150
# Epoch   77 batch   200
# Epoch   77 batch   250
# Epoch   77 batch   300
# Epoch   77 batch   350
# Epoch   77 batch   400
# Epoch   77 batch   450
# [ 24.7996254] [23]
# Epoch   77 val.cost 0.000172 val.err 11.60% stopping   5
# Epoch   78 batch     0
# Epoch   78 batch    50
# Epoch   78 batch   100
# Epoch   78 batch   150
# Epoch   78 batch   200
# Epoch   78 batch   250
# Epoch   78 batch   300
# Epoch   78 batch   350
# Epoch   78 batch   400
# Epoch   78 batch   450
# [ 11.63154125] [12]
# Epoch   78 val.cost 0.000172 val.err 11.55% stopping   6
# Epoch   79 batch     0
# Epoch   79 batch    50
# Epoch   79 batch   100
# Epoch   79 batch   150
# Epoch   79 batch   200
# Epoch   79 batch   250
# Epoch   79 batch   300
# Epoch   79 batch   350
# Epoch   79 batch   400
# Epoch   79 batch   450
# [ 29.67280388] [6]
# Epoch   79 val.cost 0.000172 val.err 11.52% best
# Epoch   80 batch     0
# Epoch   80 batch    50
# Epoch   80 batch   100
# Epoch   80 batch   150
# Epoch   80 batch   200
# Epoch   80 batch   250
# Epoch   80 batch   300
# Epoch   80 batch   350
# Epoch   80 batch   400
# Epoch   80 batch   450
# [ 21.21503448] [49]
# Epoch   80 val.cost 0.000172 val.err 11.51% best
# Epoch   81 batch     0
# Epoch   81 batch    50
# Epoch   81 batch   100
# Epoch   81 batch   150
# Epoch   81 batch   200
# Epoch   81 batch   250
# Epoch   81 batch   300
# Epoch   81 batch   350
# Epoch   81 batch   400
# Epoch   81 batch   450
# [ 76.98167419] [76]
# Epoch   81 val.cost 0.000172 val.err 11.61% stopping   1
# Epoch   82 batch     0
# Epoch   82 batch    50
# Epoch   82 batch   100
# Epoch   82 batch   150
# Epoch   82 batch   200
# Epoch   82 batch   250
# Epoch   82 batch   300
# Epoch   82 batch   350
# Epoch   82 batch   400
# Epoch   82 batch   450
# [ 74.8146286] [77]
# Epoch   82 val.cost 0.000172 val.err 11.61% stopping   2
# Epoch   83 batch     0
# Epoch   83 batch    50
# Epoch   83 batch   100
# Epoch   83 batch   150
# Epoch   83 batch   200
# Epoch   83 batch   250
# Epoch   83 batch   300
# Epoch   83 batch   350
# Epoch   83 batch   400
# Epoch   83 batch   450
# [ 33.49875641] [34]
# Epoch   83 val.cost 0.000172 val.err 11.63% stopping   3
# Epoch   84 batch     0
# Epoch   84 batch    50
# Epoch   84 batch   100
# Epoch   84 batch   150
# Epoch   84 batch   200
# Epoch   84 batch   250
# Epoch   84 batch   300
# Epoch   84 batch   350
# Epoch   84 batch   400
# Epoch   84 batch   450
# [ 29.06197166] [38]
# Epoch   84 val.cost 0.000171 val.err 11.60% stopping   4
# Epoch   85 batch     0
# Epoch   85 batch    50
# Epoch   85 batch   100
# Epoch   85 batch   150
# Epoch   85 batch   200
# Epoch   85 batch   250
# Epoch   85 batch   300
# Epoch   85 batch   350
# Epoch   85 batch   400
# Epoch   85 batch   450
# [ 25.09224319] [41]
# Epoch   85 val.cost 0.000171 val.err 11.52% stopping   5
# Epoch   86 batch     0
# Epoch   86 batch    50
# Epoch   86 batch   100
# Epoch   86 batch   150
# Epoch   86 batch   200
# Epoch   86 batch   250
# Epoch   86 batch   300
# Epoch   86 batch   350
# Epoch   86 batch   400
# Epoch   86 batch   450
# [ 30.44722176] [23]
# Epoch   86 val.cost 0.000172 val.err 11.59% stopping   6
# Epoch   87 batch     0
# Epoch   87 batch    50
# Epoch   87 batch   100
# Epoch   87 batch   150
# Epoch   87 batch   200
# Epoch   87 batch   250
# Epoch   87 batch   300
# Epoch   87 batch   350
# Epoch   87 batch   400
# Epoch   87 batch   450
# [ 96.74230957] [98]
# Epoch   87 val.cost 0.000171 val.err 11.49% best
# Epoch   88 batch     0
# Epoch   88 batch    50
# Epoch   88 batch   100
# Epoch   88 batch   150
# Epoch   88 batch   200
# Epoch   88 batch   250
# Epoch   88 batch   300
# Epoch   88 batch   350
# Epoch   88 batch   400
# Epoch   88 batch   450
# [ 78.0332489] [78]
# Epoch   88 val.cost 0.000171 val.err 11.54% stopping   1
# Epoch   89 batch     0
# Epoch   89 batch    50
# Epoch   89 batch   100
# Epoch   89 batch   150
# Epoch   89 batch   200
# Epoch   89 batch   250
# Epoch   89 batch   300
# Epoch   89 batch   350
# Epoch   89 batch   400
# Epoch   89 batch   450
# [ 55.61688995] [56]
# Epoch   89 val.cost 0.000171 val.err 11.55% stopping   2
# Epoch   90 batch     0
# Epoch   90 batch    50
# Epoch   90 batch   100
# Epoch   90 batch   150
# Epoch   90 batch   200
# Epoch   90 batch   250
# Epoch   90 batch   300
# Epoch   90 batch   350
# Epoch   90 batch   400
# Epoch   90 batch   450
# [ 3.68387604] [1]
# Epoch   90 val.cost 0.000171 val.err 11.53% stopping   3
# Epoch   91 batch     0
# Epoch   91 batch    50
# Epoch   91 batch   100
# Epoch   91 batch   150
# Epoch   91 batch   200
# Epoch   91 batch   250
# Epoch   91 batch   300
# Epoch   91 batch   350
# Epoch   91 batch   400
# Epoch   91 batch   450
# [ 28.93953133] [14]
# Epoch   91 val.cost 0.000171 val.err 11.53% stopping   4
# Epoch   92 batch     0
# Epoch   92 batch    50
# Epoch   92 batch   100
# Epoch   92 batch   150
# Epoch   92 batch   200
# Epoch   92 batch   250
# Epoch   92 batch   300
# Epoch   92 batch   350
# Epoch   92 batch   400
# Epoch   92 batch   450
# [ 31.58810806] [33]
# Epoch   92 val.cost 0.000171 val.err 11.48% best
# Epoch   93 batch     0
# Epoch   93 batch    50
# Epoch   93 batch   100
# Epoch   93 batch   150
# Epoch   93 batch   200
# Epoch   93 batch   250
# Epoch   93 batch   300
# Epoch   93 batch   350
# Epoch   93 batch   400
# Epoch   93 batch   450
# [ 13.26606464] [13]
# Epoch   93 val.cost 0.000171 val.err 11.51% stopping   1
# Epoch   94 batch     0
# Epoch   94 batch    50
# Epoch   94 batch   100
# Epoch   94 batch   150
# Epoch   94 batch   200
# Epoch   94 batch   250
# Epoch   94 batch   300
# Epoch   94 batch   350
# Epoch   94 batch   400
# Epoch   94 batch   450
# [ 37.92868805] [38]
# Epoch   94 val.cost 0.000171 val.err 11.48% stopping   2
# Epoch   95 batch     0
# Epoch   95 batch    50
# Epoch   95 batch   100
# Epoch   95 batch   150
# Epoch   95 batch   200
# Epoch   95 batch   250
# Epoch   95 batch   300
# Epoch   95 batch   350
# Epoch   95 batch   400
# Epoch   95 batch   450
# [ 24.46975899] [3]
# Epoch   95 val.cost 0.000171 val.err 11.53% stopping   3
# Epoch   96 batch     0
# Epoch   96 batch    50
# Epoch   96 batch   100
# Epoch   96 batch   150
# Epoch   96 batch   200
# Epoch   96 batch   250
# Epoch   96 batch   300
# Epoch   96 batch   350
# Epoch   96 batch   400
# Epoch   96 batch   450
# [ 31.1297493] [31]
# Epoch   96 val.cost 0.000170 val.err 11.52% stopping   4
# Epoch   97 batch     0
# Epoch   97 batch    50
# Epoch   97 batch   100
# Epoch   97 batch   150
# Epoch   97 batch   200
# Epoch   97 batch   250
# Epoch   97 batch   300
# Epoch   97 batch   350
# Epoch   97 batch   400
# Epoch   97 batch   450
# [ 47.3721199] [47]
# Epoch   97 val.cost 0.000171 val.err 11.54% stopping   5
# Epoch   98 batch     0
# Epoch   98 batch    50
# Epoch   98 batch   100
# Epoch   98 batch   150
# Epoch   98 batch   200
# Epoch   98 batch   250
# Epoch   98 batch   300
# Epoch   98 batch   350
# Epoch   98 batch   400
# Epoch   98 batch   450
# [ 52.28030777] [52]
# Epoch   98 val.cost 0.000171 val.err 11.64% stopping   6
# Epoch   99 batch     0
# Epoch   99 batch    50
# Epoch   99 batch   100
# Epoch   99 batch   150

# %%
predicted_df = pd.DataFrame({'PM2.5':predicted_values[:,0]})
dw['PM2.5']=predicted_df['PM2.5']
dw.to_csv('./predict_no_LatLon.csv', index=False)
